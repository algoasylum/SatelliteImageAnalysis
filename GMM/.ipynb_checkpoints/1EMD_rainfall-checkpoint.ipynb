# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import mixture
sns.set(style='whitegrid')
sns.set_palette('bright')
import warnings
warnings.filterwarnings('ignore')
import collections
from scipy.spatial import distance
from scipy.stats import norm
from scipy import stats
from scipy.stats import wasserstein_distance

# %%
df = pd.read_csv('preci_alt.csv')
df.columns = ['date','value']
df.date = pd.to_datetime(df.date,format='%b %d, %Y')
df.head(3)
# Out:
#         date  value
# 0 2010-01-01    0.0
# 1 2010-01-02    0.0
# 2 2010-01-03    0.0

# %%
df2019 = df[(df.date.dt.year == 2019) & ((df.date.dt.month == 6)|(df.date.dt.month == 7)|(df.date.dt.month == 8))]
df2018 = df[(df.date.dt.year == 2018) & ((df.date.dt.month == 6)|(df.date.dt.month == 7)|(df.date.dt.month == 8))]
df2017 = df[(df.date.dt.year == 2017) & ((df.date.dt.month == 6)|(df.date.dt.month == 7)|(df.date.dt.month == 8))]
df2016 = df[(df.date.dt.year == 2016) & ((df.date.dt.month == 6)|(df.date.dt.month == 7)|(df.date.dt.month == 8))]
df2019
# Out:
#            date  value
# 3438 2019-06-01  0.000
# 3439 2019-06-02  0.000
# 3440 2019-06-03  0.000
# 3441 2019-06-04  0.000
# 3442 2019-06-05  0.001
# ...         ...    ...
# 3525 2019-08-27  0.002
# 3526 2019-08-28  0.002
# 3527 2019-08-29  0.002
# 3528 2019-08-30  0.014
# 3529 2019-08-31  0.007
#
# [92 rows x 2 columns]

# %%
sns.distplot(df2019.value)
# Out:
# <AxesSubplot:xlabel='value', ylabel='Density'>

# %%
sns.distplot(df2019.value)
sns.distplot(df2018.value)
# Out:
# <AxesSubplot:xlabel='value', ylabel='Density'>

# %%
sns.distplot(df2018.value)
sns.distplot(df2017.value)
# Out:
# <AxesSubplot:xlabel='value', ylabel='Density'>

# %%
wasserstein_distance(df2019.value,df2018.value)
# Out:
# 0.004543478260869566

# %%
wasserstein_distance(df2018.value,df2017.value)
# Out:
# 0.002195652173913045

# %%
df19 = df[df.date.dt.year==2019]
a = np.zeros(shape=(12, 12))
for i in range(0,12):
    for j in range(0,12):
        dff = df19[df19.date.dt.month == i+1]
        dfj = df19[df19.date.dt.month == j+1]
        x = wasserstein_distance(dff.value,dfj.value)
        a[i][j] = x

# %%
dfw = pd.DataFrame(a)
cm = sns.light_palette("green", as_cmap=True)
s = dfw.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_004f1_row0_col0,#T_004f1_row0_col1,#T_004f1_row0_col2,#T_004f1_row0_col4,#T_004f1_row1_col0,#T_004f1_row1_col1,#T_004f1_row1_col2,#T_004f1_row1_col4,#T_004f1_row2_col0,#T_004f1_row2_col1,#T_004f1_row2_col2,#T_004f1_row2_col4,#T_004f1_row3_col3,#T_004f1_row4_col0,#T_004f1_row4_col1,#T_004f1_row4_col2,#T_004f1_row4_col4,#T_004f1_row5_col5,#T_004f1_row6_col6,#T_004f1_row7_col7,#T_004f1_row8_col8,#T_004f1_row9_col9,#T_004f1_row10_col10,#T_004f1_row11_col11{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_004f1_row0_col3,#T_004f1_row1_col3,#T_004f1_row2_col3,#T_004f1_row3_col0,#T_004f1_row3_col1,#T_004f1_row3_col2,#T_004f1_row3_col4,#T_004f1_row4_col3{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_004f1_row0_col5,#T_004f1_row1_col5,#T_004f1_row2_col5,#T_004f1_row4_col5,#T_004f1_row11_col6,#T_004f1_row11_col8{
#             background-color:  #0a850a;
#             color:  #f1f1f1;
#         }#T_004f1_row0_col6,#T_004f1_row0_col7,#T_004f1_row0_col8,#T_004f1_row1_col6,#T_004f1_row1_col7,#T_004f1_row1_col8,#T_004f1_row2_col6,#T_004f1_row2_col7,#T_004f1_row2_col8,#T_004f1_row4_col6,#T_004f1_row4_col7,#T_004f1_row4_col8,#T_004f1_row7_col0,#T_004f1_row7_col1,#T_004f1_row7_col2,#T_004f1_row7_col3,#T_004f1_row7_col4,#T_004f1_row7_col5,#T_004f1_row7_col9,#T_004f1_row7_col10,#T_004f1_row7_col11{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_004f1_row0_col9,#T_004f1_row1_col9,#T_004f1_row2_col9,#T_004f1_row4_col9,#T_004f1_row6_col3,#T_004f1_row6_col11{
#             background-color:  #399c39;
#             color:  #000000;
#         }#T_004f1_row0_col10,#T_004f1_row1_col10,#T_004f1_row2_col10,#T_004f1_row4_col10,#T_004f1_row10_col0,#T_004f1_row10_col1,#T_004f1_row10_col2,#T_004f1_row10_col4{
#             background-color:  #e1eee1;
#             color:  #000000;
#         }#T_004f1_row0_col11,#T_004f1_row1_col11,#T_004f1_row2_col11,#T_004f1_row4_col11,#T_004f1_row11_col0,#T_004f1_row11_col1,#T_004f1_row11_col2,#T_004f1_row11_col4{
#             background-color:  #e3efe3;
#             color:  #000000;
#         }#T_004f1_row3_col5{
#             background-color:  #158a15;
#             color:  #000000;
#         }#T_004f1_row3_col6,#T_004f1_row3_col8,#T_004f1_row11_col7{
#             background-color:  #078407;
#             color:  #f1f1f1;
#         }#T_004f1_row3_col7{
#             background-color:  #068306;
#             color:  #f1f1f1;
#         }#T_004f1_row3_col9{
#             background-color:  #43a143;
#             color:  #000000;
#         }#T_004f1_row3_col10,#T_004f1_row10_col3,#T_004f1_row10_col11,#T_004f1_row11_col10{
#             background-color:  #e7f1e7;
#             color:  #000000;
#         }#T_004f1_row3_col11,#T_004f1_row11_col3{
#             background-color:  #e8f2e8;
#             color:  #000000;
#         }#T_004f1_row5_col0,#T_004f1_row5_col1,#T_004f1_row5_col2,#T_004f1_row5_col4{
#             background-color:  #78bb78;
#             color:  #000000;
#         }#T_004f1_row5_col3{
#             background-color:  #7bbc7b;
#             color:  #000000;
#         }#T_004f1_row5_col6{
#             background-color:  #6db66d;
#             color:  #000000;
#         }#T_004f1_row5_col7,#T_004f1_row6_col9{
#             background-color:  #73b873;
#             color:  #000000;
#         }#T_004f1_row5_col8{
#             background-color:  #6bb46b;
#             color:  #000000;
#         }#T_004f1_row5_col9{
#             background-color:  #91c791;
#             color:  #000000;
#         }#T_004f1_row5_col10{
#             background-color:  #7dbd7d;
#             color:  #000000;
#         }#T_004f1_row5_col11{
#             background-color:  #7cbd7c;
#             color:  #000000;
#         }#T_004f1_row6_col0,#T_004f1_row6_col1,#T_004f1_row6_col2,#T_004f1_row6_col4,#T_004f1_row8_col3{
#             background-color:  #379b37;
#             color:  #000000;
#         }#T_004f1_row6_col5{
#             background-color:  #2f972f;
#             color:  #000000;
#         }#T_004f1_row6_col7{
#             background-color:  #6db56d;
#             color:  #000000;
#         }#T_004f1_row6_col8,#T_004f1_row8_col6{
#             background-color:  #b0d6b0;
#             color:  #000000;
#         }#T_004f1_row6_col10{
#             background-color:  #3a9c3a;
#             color:  #000000;
#         }#T_004f1_row7_col6{
#             background-color:  #45a245;
#             color:  #000000;
#         }#T_004f1_row7_col8{
#             background-color:  #6fb76f;
#             color:  #000000;
#         }#T_004f1_row8_col0,#T_004f1_row8_col1,#T_004f1_row8_col2,#T_004f1_row8_col4{
#             background-color:  #369b36;
#             color:  #000000;
#         }#T_004f1_row8_col5{
#             background-color:  #299429;
#             color:  #000000;
#         }#T_004f1_row8_col7,#T_004f1_row9_col6{
#             background-color:  #8cc58c;
#             color:  #000000;
#         }#T_004f1_row8_col9{
#             background-color:  #70b770;
#             color:  #000000;
#         }#T_004f1_row8_col10,#T_004f1_row8_col11{
#             background-color:  #389b38;
#             color:  #000000;
#         }#T_004f1_row9_col0,#T_004f1_row9_col1,#T_004f1_row9_col2,#T_004f1_row9_col4{
#             background-color:  #80bf80;
#             color:  #000000;
#         }#T_004f1_row9_col3{
#             background-color:  #84c084;
#             color:  #000000;
#         }#T_004f1_row9_col5{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_004f1_row9_col7{
#             background-color:  #5dae5d;
#             color:  #000000;
#         }#T_004f1_row9_col8{
#             background-color:  #8bc48b;
#             color:  #000000;
#         }#T_004f1_row9_col10{
#             background-color:  #85c185;
#             color:  #000000;
#         }#T_004f1_row9_col11{
#             background-color:  #84c184;
#             color:  #000000;
#         }#T_004f1_row10_col5{
#             background-color:  #1c8e1c;
#             color:  #000000;
#         }#T_004f1_row10_col6,#T_004f1_row10_col8{
#             background-color:  #0c860c;
#             color:  #f1f1f1;
#         }#T_004f1_row10_col7{
#             background-color:  #098509;
#             color:  #f1f1f1;
#         }#T_004f1_row10_col9{
#             background-color:  #49a449;
#             color:  #000000;
#         }#T_004f1_row11_col5{
#             background-color:  #198c19;
#             color:  #000000;
#         }#T_004f1_row11_col9{
#             background-color:  #47a347;
#             color:  #000000;
#         }</style><table id="T_004f1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>        <th class="col_heading level0 col10" >10</th>        <th class="col_heading level0 col11" >11</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_004f1_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_004f1_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_004f1_row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_004f1_row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_004f1_row0_col3" class="data row0 col3" >0.000367</td>
#                         <td id="T_004f1_row0_col4" class="data row0 col4" >0.000000</td>
#                         <td id="T_004f1_row0_col5" class="data row0 col5" >0.007033</td>
#                         <td id="T_004f1_row0_col6" class="data row0 col6" >0.010968</td>
#                         <td id="T_004f1_row0_col7" class="data row0 col7" >0.014387</td>

# %%
plt.imshow(a, interpolation='none')
plt.show()

# %%
df19 = df[df.date.dt.year==2019]
df20 = df[df.date.dt.year==2018]
a = np.zeros(shape=(12, 12))
for i in range(0,12):
    for j in range(0,12):
        dff = df19[df19.date.dt.month == i+1]
        dfj = df20[df20.date.dt.month == j+1]
        x = wasserstein_distance(dff.value,dfj.value)
        a[i][j] = x

# %%
dfw = pd.DataFrame(a)
cm = sns.light_palette("green", as_cmap=True)
s = dfw.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_7809f_row0_col0,#T_7809f_row0_col1,#T_7809f_row0_col2,#T_7809f_row0_col4,#T_7809f_row0_col11,#T_7809f_row1_col0,#T_7809f_row1_col1,#T_7809f_row1_col2,#T_7809f_row1_col4,#T_7809f_row1_col11,#T_7809f_row2_col0,#T_7809f_row2_col1,#T_7809f_row2_col2,#T_7809f_row2_col4,#T_7809f_row2_col11,#T_7809f_row3_col3,#T_7809f_row3_col4,#T_7809f_row4_col0,#T_7809f_row4_col1,#T_7809f_row4_col2,#T_7809f_row4_col4,#T_7809f_row4_col11,#T_7809f_row6_col6,#T_7809f_row9_col5,#T_7809f_row9_col7,#T_7809f_row10_col8,#T_7809f_row10_col9,#T_7809f_row10_col10,#T_7809f_row11_col4,#T_7809f_row11_col9,#T_7809f_row11_col10{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_7809f_row0_col3,#T_7809f_row1_col3,#T_7809f_row2_col3,#T_7809f_row4_col3,#T_7809f_row11_col8{
#             background-color:  #eaf2ea;
#             color:  #000000;
#         }#T_7809f_row0_col5,#T_7809f_row1_col5,#T_7809f_row2_col5,#T_7809f_row4_col5{
#             background-color:  #4aa44a;
#             color:  #000000;
#         }#T_7809f_row0_col6,#T_7809f_row1_col6,#T_7809f_row2_col6,#T_7809f_row4_col6,#T_7809f_row7_col0,#T_7809f_row7_col1,#T_7809f_row7_col2,#T_7809f_row7_col3,#T_7809f_row7_col4,#T_7809f_row7_col5,#T_7809f_row7_col7,#T_7809f_row7_col8,#T_7809f_row7_col9,#T_7809f_row7_col10,#T_7809f_row7_col11{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_7809f_row0_col7,#T_7809f_row1_col7,#T_7809f_row2_col7,#T_7809f_row4_col7{
#             background-color:  #3f9f3f;
#             color:  #000000;
#         }#T_7809f_row0_col8,#T_7809f_row1_col8,#T_7809f_row2_col8,#T_7809f_row4_col8{
#             background-color:  #dfeddf;
#             color:  #000000;
#         }#T_7809f_row0_col9,#T_7809f_row1_col9,#T_7809f_row2_col9,#T_7809f_row4_col9{
#             background-color:  #e2efe2;
#             color:  #000000;
#         }#T_7809f_row0_col10,#T_7809f_row1_col10,#T_7809f_row2_col10,#T_7809f_row4_col10,#T_7809f_row11_col0,#T_7809f_row11_col1,#T_7809f_row11_col2,#T_7809f_row11_col11{
#             background-color:  #e3efe3;
#             color:  #000000;
#         }#T_7809f_row3_col0,#T_7809f_row3_col1,#T_7809f_row3_col2,#T_7809f_row3_col11{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_7809f_row3_col5{
#             background-color:  #56aa56;
#             color:  #000000;
#         }#T_7809f_row3_col6{
#             background-color:  #0a850a;
#             color:  #f1f1f1;
#         }#T_7809f_row3_col7{
#             background-color:  #4ba54a;
#             color:  #000000;
#         }#T_7809f_row3_col8,#T_7809f_row10_col4{
#             background-color:  #e7f1e7;
#             color:  #000000;
#         }#T_7809f_row3_col9,#T_7809f_row3_col10,#T_7809f_row11_col3{
#             background-color:  #e9f2e9;
#             color:  #000000;
#         }#T_7809f_row5_col0,#T_7809f_row5_col1,#T_7809f_row5_col2,#T_7809f_row5_col11{
#             background-color:  #78bb78;
#             color:  #000000;
#         }#T_7809f_row5_col3{
#             background-color:  #7bbc7b;
#             color:  #000000;
#         }#T_7809f_row5_col4{
#             background-color:  #7dbd7d;
#             color:  #000000;
#         }#T_7809f_row5_col5{
#             background-color:  #98ca98;
#             color:  #000000;
#         }#T_7809f_row5_col6{
#             background-color:  #63b163;
#             color:  #000000;
#         }#T_7809f_row5_col7{
#             background-color:  #afd6af;
#             color:  #000000;
#         }#T_7809f_row5_col8{
#             background-color:  #9ccd9c;
#             color:  #000000;
#         }#T_7809f_row5_col9,#T_7809f_row9_col0,#T_7809f_row9_col1,#T_7809f_row9_col2,#T_7809f_row9_col11{
#             background-color:  #80bf80;
#             color:  #000000;
#         }#T_7809f_row5_col10{
#             background-color:  #7fbe7f;
#             color:  #000000;
#         }#T_7809f_row6_col0,#T_7809f_row6_col1,#T_7809f_row6_col2,#T_7809f_row6_col11,#T_7809f_row8_col3{
#             background-color:  #379b37;
#             color:  #000000;
#         }#T_7809f_row6_col3,#T_7809f_row8_col9,#T_7809f_row8_col10{
#             background-color:  #399c39;
#             color:  #000000;
#         }#T_7809f_row6_col4{
#             background-color:  #3a9c3a;
#             color:  #000000;
#         }#T_7809f_row6_col5{
#             background-color:  #8bc48b;
#             color:  #000000;
#         }#T_7809f_row6_col7{
#             background-color:  #b7dab7;
#             color:  #000000;
#         }#T_7809f_row6_col8{
#             background-color:  #49a449;
#             color:  #000000;
#         }#T_7809f_row6_col9,#T_7809f_row6_col10{
#             background-color:  #3b9d3b;
#             color:  #000000;
#         }#T_7809f_row7_col6{
#             background-color:  #219021;
#             color:  #000000;
#         }#T_7809f_row8_col0,#T_7809f_row8_col1,#T_7809f_row8_col2,#T_7809f_row8_col11{
#             background-color:  #369b36;
#             color:  #000000;
#         }#T_7809f_row8_col4{
#             background-color:  #389b38;
#             color:  #000000;
#         }#T_7809f_row8_col5{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_7809f_row8_col6{
#             background-color:  #b2d7b2;
#             color:  #000000;
#         }#T_7809f_row8_col7{
#             background-color:  #99cb99;
#             color:  #000000;
#         }#T_7809f_row8_col8{
#             background-color:  #47a347;
#             color:  #000000;
#         }#T_7809f_row9_col3{
#             background-color:  #84c084;
#             color:  #000000;
#         }#T_7809f_row9_col4{
#             background-color:  #85c185;
#             color:  #000000;
#         }#T_7809f_row9_col6{
#             background-color:  #b4d8b4;
#             color:  #000000;
#         }#T_7809f_row9_col8{
#             background-color:  #a7d2a7;
#             color:  #000000;
#         }#T_7809f_row9_col9{
#             background-color:  #88c388;
#             color:  #000000;
#         }#T_7809f_row9_col10{
#             background-color:  #87c287;
#             color:  #000000;
#         }#T_7809f_row10_col0,#T_7809f_row10_col1,#T_7809f_row10_col2,#T_7809f_row10_col11{
#             background-color:  #e1eee1;
#             color:  #000000;
#         }#T_7809f_row10_col3{
#             background-color:  #e8f2e8;
#             color:  #000000;
#         }#T_7809f_row10_col5{
#             background-color:  #5bad5b;
#             color:  #000000;
#         }#T_7809f_row10_col6{
#             background-color:  #108810;
#             color:  #f1f1f1;
#         }#T_7809f_row10_col7{
#             background-color:  #52a852;
#             color:  #000000;
#         }#T_7809f_row11_col5{
#             background-color:  #59ac59;
#             color:  #000000;
#         }#T_7809f_row11_col6{
#             background-color:  #0e870e;
#             color:  #f1f1f1;
#         }#T_7809f_row11_col7{
#             background-color:  #4fa74f;
#             color:  #000000;
#         }</style><table id="T_7809f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>        <th class="col_heading level0 col10" >10</th>        <th class="col_heading level0 col11" >11</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7809f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7809f_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_7809f_row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_7809f_row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_7809f_row0_col3" clas

# %%
df2019
# Out:
#            date  value
# 3438 2019-06-01  0.000
# 3439 2019-06-02  0.000
# 3440 2019-06-03  0.000
# 3441 2019-06-04  0.000
# 3442 2019-06-05  0.001
# ...         ...    ...
# 3525 2019-08-27  0.002
# 3526 2019-08-28  0.002
# 3527 2019-08-29  0.002
# 3528 2019-08-30  0.014
# 3529 2019-08-31  0.007
#
# [92 rows x 2 columns]
