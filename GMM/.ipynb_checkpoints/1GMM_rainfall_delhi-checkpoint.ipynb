# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import mixture
sns.set(style='whitegrid')
sns.set_palette('bright')
import warnings
warnings.filterwarnings('ignore')
import collections
from scipy.spatial import distance

# %%
df = pd.read_csv('preci_alt.csv')
df.columns = ['date','value']
df.date = pd.to_datetime(df.date,format='%b %d, %Y')
df.head(3)
# Out:
#         date  value
# 0 2010-01-01    0.0
# 1 2010-01-02    0.0
# 2 2010-01-03    0.0

# %%
df19 = df[df.date.dt.year==2019]

# %%
def gmm2k(q1,q2):
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 8)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            q1 = np.asarray(q1)
            q1 =q1.reshape(-1,1)
            gmm.fit(q1)
            bic.append(gmm.bic(q1))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmmq1 = gmm
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 8)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            q2 = np.asarray(q2)
            q2 =q2.reshape(-1,1)
            gmm.fit(q2)
            bic.append(gmm.bic(q2))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmmq2 = gmm
    mins = min(best_gmmq1.n_components,best_gmmq2.n_components)
    if best_gmmq1.n_components > best_gmmq2.n_components:
        lowest_bic = np.infty
        bic = []
        cv_types = ['spherical', 'tied', 'diag', 'full']
        for cv_type in cv_types:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=mins,
                                              covariance_type=cv_type)
            q1 = np.asarray(q1)
            q1 =q1.reshape(-1,1)
            gmm.fit(q1)
            bic.append(gmm.bic(q1))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmmq1 = gmm
    else:
        lowest_bic = np.infty
        bic = []
        cv_types = ['spherical', 'tied', 'diag', 'full']
        for cv_type in cv_types:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=mins,
                                              covariance_type=cv_type)
            q2 = np.asarray(q2)
            q2 =q2.reshape(-1,1)
            gmm.fit(q2)
            bic.append(gmm.bic(q2))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmmq2 = gmm
    #print(best_gmmq1.get_params())
    #print(best_gmmq2.get_params())
    #print(best_gmmq1.means_)
    #print(best_gmmq2.means_)
    #print(best_gmmq1.weights_)
    #print(best_gmmq2.weights_)
    means=[]
    for tt in range(len(best_gmmq1.means_)):
        means.append(best_gmmq1.means_[tt][0])
    x = dict(zip(best_gmmq1.weights_,means))
    od1 = collections.OrderedDict(sorted(x.items(),reverse=True))
    od1 = list(zip(list(od1.keys()),list(od1.values())))
    means=[]
    for tt in range(len(best_gmmq2.means_)):
        means.append(best_gmmq2.means_[tt][0])
    y = dict(zip(best_gmmq2.weights_,means))
    od2 = collections.OrderedDict(sorted(y.items(),reverse=True))
    od2 = list(zip(list(od2.keys()),list(od2.values())))
    #print(od1)
    #print(od2)
    diffmean = []
    diffweights = []
    for tt in range(len(od2)):
        diffmean.append(od1[tt][1] - od2[tt][1])
        diffweights.append(od1[tt][0] - od2[tt][0]) 
    print(diffweights)
    r=[]
    for i in range(0,len(diffmean)):
        r.append(diffmean[i] * diffweights[i] * 10000)
    return od1,od2,sum(r)

# %%
def gmm10k(q1,q2):
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 8)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            q1 = np.asarray(q1)
            q1 =q1.reshape(-1,1)
            gmm.fit(q1)
            bic.append(gmm.bic(q1))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmmq1 = gmm
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 8)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            q2 = np.asarray(q2)
            q2 =q2.reshape(-1,1)
            gmm.fit(q2)
            bic.append(gmm.bic(q2))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmmq2 = gmm
    
    #print(best_gmmq1.get_params())
    #print(best_gmmq2.get_params())
    #print(best_gmmq1.means_)
    #print(best_gmmq2.means_)
    #print(best_gmmq1.weights_)
    #print(best_gmmq2.weights_)
    means=[]
    for tt in range(len(best_gmmq1.means_)):
        means.append(best_gmmq1.means_[tt][0])
    x = dict(zip(best_gmmq1.weights_,means))
    od1 = collections.OrderedDict(sorted(x.items(),reverse=True))
    od1 = list(zip(list(od1.keys()),list(od1.values())))
    means=[]
    for tt in range(len(best_gmmq2.means_)):
        means.append(best_gmmq2.means_[tt][0])
    y = dict(zip(best_gmmq2.weights_,means))
    od2 = collections.OrderedDict(sorted(y.items(),reverse=True))
    od2 = list(zip(list(od2.keys()),list(od2.values())))
    maxx = max(len(od1),len(od2))
    diff = abs(len(od1) - len(od2))
    if len(od2) > len(od1):
        for i in range(0,diff):
            od1.append((0,0))
    elif len(od2) < len(od1):
        for i in range(0,diff):
            od2.append((0,0))
    #print(maxx)
    #print(od1)
    #print(od2)
    diffmean = []
    diffweights = []
    for tt in range(len(od2)):
        diffmean.append(od1[tt][1] - od2[tt][1])
        diffweights.append(od1[tt][0] - od2[tt][0]) 
    #print(diffweights)
    r=[]
    for i in range(0,len(diffmean)):
        r.append(diffmean[i] * diffweights[i])
    #print(len(od1) , len(od2))
    return od1,od2,sum(r)

# %%
def gmm20k(q1,q2):
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 8)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            q1 = np.asarray(q1)
            q1 =q1.reshape(-1,1)
            gmm.fit(q1)
            bic.append(gmm.bic(q1))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmmq1 = gmm
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 8)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            q2 = np.asarray(q2)
            q2 =q2.reshape(-1,1)
            gmm.fit(q2)
            bic.append(gmm.bic(q2))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmmq2 = gmm
    
    means=[]
    for tt in range(len(best_gmmq1.means_)):
        means.append(best_gmmq1.means_[tt][0])
    x = dict(zip(means,best_gmmq1.weights_))
    od1 = collections.OrderedDict(sorted(x.items(),reverse=True))
    od1 = list(zip(list(od1.keys()),list(od1.values())))
    #print(od1)
    means=[]
    for tt in range(len(best_gmmq2.means_)):
        means.append(best_gmmq2.means_[tt][0])
    y = dict(zip(means,best_gmmq2.weights_))
    od2 = collections.OrderedDict(sorted(y.items(),reverse=True))
    od2 = list(zip(list(od2.keys()),list(od2.values())))
    #print(od2)
    maxx = max(len(od1),len(od2))
    diff = abs(len(od1) - len(od2))
    if len(od2) > len(od1):
        for i in range(0,diff):
            od1.append((0,0))
    elif len(od2) < len(od1):
        for i in range(0,diff):
            od2.append((0,0))

    diffmean = []
    diffweights = []
    for tt in range(len(od2)):
        diffmean.append(abs(od1[tt][1] - od2[tt][1]))
        diffweights.append(abs(od1[tt][0] - od2[tt][0])) 
    #print(diffweights)
    r=[]
    for i in range(0,len(diffmean)):
        r.append(diffmean[i] * diffweights[i])
    #print(len(od1) , len(od2))
    return od1,od2,sum(r)

# %%
df19j = df19[df19.date.dt.month == 7]
df19f = df19[df19.date.dt.month == 6]
qw,we,r= gmm10k(df19j.value,df19f.value)
print(qw)
print(we)
print(r)
# Out:
# [(0.9323576903819809, 0.009093045896577728), (0.06764230961801904, 0.036807889601541174), (0, 0)]
# [(0.6427045173822165, 0.0017537042888375555), (0.29050665528132114, 0.008505409622636165), (0.0667888273364624, 0.05143587184378962)]
# -0.0007464085332609676

# %%
df19j = df19[df19.date.dt.month == 7]
df19f = df19[df19.date.dt.month == 6]
qw,we,r= gmm2k(df19j.value,df19f.value)
print(qw)
print(we)
print(r)
# Out:
# [-6.761106450792198e-05, 6.761106450806076e-05]
# [(0.9323576903819809, 0.009093045896577728), (0.06764230961801905, 0.03680788960154117)]
# [(0.9324253014464888, 0.003844462857303236), (0.06757469855351099, 0.05103476550445302)]
# -0.013167565108635211

# %%
a = np.zeros(shape=(12, 12))
for i in range(1,13):
    for j in range(1,13):
        dfc = df19[df19.date.dt.month == i]
        dfd = df19[df19.date.dt.month == j]
        _,_,r = gmm10k(dfc.value,dfd.value)
        a[i-1][j-1] = r
a
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  5.27962904e-03,
#          1.86389899e-03,  1.23351598e-02,  7.42092362e-03,
#          3.45175380e-03,  4.90084299e-04,  3.26828713e-04],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  5.26154842e-03,
#          1.87469604e-03,  1.23351598e-02,  7.42092362e-03,
#          3.45175380e-03,  4.90084299e-04,  3.26828713e-04],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  5.27962904e-03,
#          1.86389899e-03,  1.23351598e-02,  7.42092362e-03,
#          3.45175380e-03,  4.90084299e-04,  3.26828713e-04],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  5.39216239e-03,
#          1.89949822e-03,  1.24940828e-02,  7.56996656e-03,
#          3.55369924e-03,  5.26619396e-04,  3.60593568e-04],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.98560794e-03,
#          1.87469604e-03,  1.23351598e-02,  7.42092362e-03,
#          3.45175380e-03,  4.90084299e-04,  3.26828713e-04],
#        [ 5.27962904e-03,  5.27962904e-03,  5.27962904e-03,
#          5.41063739e-03,  3.07086023e-03,  3.56265543e-08,
#         -7.94884014e-04,  2.90177288e-03,  4.89596893e-03,
#          3.73231646e-03,  3.67322572e-03,  1.39706138e-03],
#        [ 1.87469604e-03,  1.87469604e-03,  1.86389899e-03,
#          1.89949822e-03,  1.86389899e-03, -7.51979398e-04,
#          0.00000000e+00,  3.38634350e-03, -3.20484370e-03,
#         -4.96802667e-03, -7.29457310e-04, -5.90697495e-04],
#        [ 1.23351598e-02,  1.23351598e-02,  1.23351598e-02,
#          1.24940828e-02,  1.23351598e-02,  7.65635369e-04,
#          3.38036057e-03,  0.00000000e+00,  6.13006626e-03,
#          2.92966311e-03,  9.26884556e-03,  9.74832018e-03],
#        [ 7.42092362e-03,  7.42092362e-03,  7.42092362e-03,
#          7.56996656e-03,  7.42092362e-03,  3.87472131e-03,
#         -3.20484370e-03,  6.13006626e-03, -7.67646727e-08,
#          4.30998502e-04,  4.09263467e-03,  4.62391399e-03],
#        [ 3.45175380e-03,  3.45175380e-03,  3.45175380e-03,
#          3.55369924e-03,  3.45175380e-03,  1.51435827e-04,
#         -4.96161701e-03,  2.92966311e-03,  2.23017959e-03,
#          0.00000000e+00,  1.68562086e-03,  1.94325271e-03],
#        [ 4.90084299e-04,  4.90084299e-04,  4.90084299e-04,
#          5.26619396e-04,  4.90084299e-04,  3.67322572e-03,
#         -7.51471159e-04,  9.26884556e-03,  4.09263467e-03,
#          1.35752392e-03,  0.00000000e+00,  1.03455089e-05],
#        [ 3.26828713e-04,  3.26828713e-04,  3.26828713e-04,
#          3.60593568e-04,  3.26828713e-04,  3.96407744e-03,
#         -5.90697495e-04,  9.74832018e-03,  4.62391399e-03,
#          1.74752048e-03,  1.03455089e-05,  0.00000000e+00]])

# %%
dfw = pd.DataFrame(a)
cm = sns.light_palette("green", as_cmap=True)
s = dfw.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_7cac1_row0_col0,#T_7cac1_row0_col1,#T_7cac1_row0_col2,#T_7cac1_row0_col3,#T_7cac1_row0_col4,#T_7cac1_row1_col0,#T_7cac1_row1_col1,#T_7cac1_row1_col2,#T_7cac1_row1_col3,#T_7cac1_row1_col4,#T_7cac1_row2_col0,#T_7cac1_row2_col1,#T_7cac1_row2_col2,#T_7cac1_row2_col3,#T_7cac1_row2_col4,#T_7cac1_row3_col0,#T_7cac1_row3_col1,#T_7cac1_row3_col2,#T_7cac1_row3_col3,#T_7cac1_row3_col4,#T_7cac1_row4_col0,#T_7cac1_row4_col1,#T_7cac1_row4_col2,#T_7cac1_row4_col3,#T_7cac1_row4_col4,#T_7cac1_row6_col5,#T_7cac1_row6_col8,#T_7cac1_row6_col9,#T_7cac1_row6_col10,#T_7cac1_row6_col11,#T_7cac1_row7_col7,#T_7cac1_row9_col6{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_7cac1_row0_col5,#T_7cac1_row2_col5{
#             background-color:  #048204;
#             color:  #f1f1f1;
#         }#T_7cac1_row0_col6,#T_7cac1_row1_col6,#T_7cac1_row2_col6,#T_7cac1_row4_col6{
#             background-color:  #2a952a;
#             color:  #000000;
#         }#T_7cac1_row0_col7,#T_7cac1_row0_col8,#T_7cac1_row1_col7,#T_7cac1_row1_col8,#T_7cac1_row2_col7,#T_7cac1_row2_col8,#T_7cac1_row4_col7,#T_7cac1_row4_col8{
#             background-color:  #038103;
#             color:  #f1f1f1;
#         }#T_7cac1_row0_col9,#T_7cac1_row1_col9,#T_7cac1_row2_col9,#T_7cac1_row4_col9{
#             background-color:  #078407;
#             color:  #f1f1f1;
#         }#T_7cac1_row0_col10,#T_7cac1_row1_col10,#T_7cac1_row2_col10,#T_7cac1_row4_col10,#T_7cac1_row5_col5{
#             background-color:  #cee5ce;
#             color:  #000000;
#         }#T_7cac1_row0_col11,#T_7cac1_row1_col11,#T_7cac1_row2_col11,#T_7cac1_row4_col11{
#             background-color:  #d6e9d6;
#             color:  #000000;
#         }#T_7cac1_row1_col5,#T_7cac1_row3_col9{
#             background-color:  #058205;
#             color:  #f1f1f1;
#         }#T_7cac1_row3_col5,#T_7cac1_row3_col7,#T_7cac1_row3_col8,#T_7cac1_row5_col9,#T_7cac1_row7_col0,#T_7cac1_row7_col1,#T_7cac1_row7_col2,#T_7cac1_row7_col3,#T_7cac1_row7_col4,#T_7cac1_row7_col6,#T_7cac1_row7_col10,#T_7cac1_row7_col11{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_7cac1_row3_col6{
#             background-color:  #299429;
#             color:  #000000;
#         }#T_7cac1_row3_col10{
#             background-color:  #cde5cd;
#             color:  #000000;
#         }#T_7cac1_row3_col11{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_7cac1_row4_col5,#T_7cac1_row8_col3{
#             background-color:  #5cad5c;
#             color:  #000000;
#         }#T_7cac1_row5_col0,#T_7cac1_row5_col1,#T_7cac1_row5_col2{
#             background-color:  #86c286;
#             color:  #000000;
#         }#T_7cac1_row5_col3{
#             background-color:  #85c185;
#             color:  #000000;
#         }#T_7cac1_row5_col4,#T_7cac1_row7_col5{
#             background-color:  #b1d7b1;
#             color:  #000000;
#         }#T_7cac1_row5_col6{
#             background-color:  #76ba76;
#             color:  #000000;
#         }#T_7cac1_row5_col7{
#             background-color:  #b4d8b4;
#             color:  #000000;
#         }#T_7cac1_row5_col8,#T_7cac1_row8_col5{
#             background-color:  #3a9c3a;
#             color:  #000000;
#         }#T_7cac1_row5_col10{
#             background-color:  #84c084;
#             color:  #000000;
#         }#T_7cac1_row5_col11{
#             background-color:  #bdddbd;
#             color:  #000000;
#         }#T_7cac1_row6_col0,#T_7cac1_row6_col1,#T_7cac1_row6_col2,#T_7cac1_row6_col3,#T_7cac1_row6_col4{
#             background-color:  #c8e2c8;
#             color:  #000000;
#         }#T_7cac1_row6_col6{
#             background-color:  #5fae5f;
#             color:  #000000;
#         }#T_7cac1_row6_col7{
#             background-color:  #abd4ab;
#             color:  #000000;
#         }#T_7cac1_row7_col8{
#             background-color:  #1f8f1f;
#             color:  #000000;
#         }#T_7cac1_row7_col9{
#             background-color:  #158a15;
#             color:  #000000;
#         }#T_7cac1_row8_col0,#T_7cac1_row8_col1,#T_7cac1_row8_col2,#T_7cac1_row8_col4{
#             background-color:  #5dae5d;
#             color:  #000000;
#         }#T_7cac1_row8_col6{
#             background-color:  #badbba;
#             color:  #000000;
#         }#T_7cac1_row8_col7{
#             background-color:  #78bb78;
#             color:  #000000;
#         }#T_7cac1_row8_col8{
#             background-color:  #a5d1a5;
#             color:  #000000;
#         }#T_7cac1_row8_col9{
#             background-color:  #59ac59;
#             color:  #000000;
#         }#T_7cac1_row8_col10{
#             background-color:  #79bc79;
#             color:  #000000;
#         }#T_7cac1_row8_col11,#T_7cac1_row9_col8,#T_7cac1_row10_col6{
#             background-color:  #74b974;
#             color:  #000000;
#         }#T_7cac1_row9_col0,#T_7cac1_row9_col1,#T_7cac1_row9_col2,#T_7cac1_row9_col4{
#             background-color:  #a9d3a9;
#             color:  #000000;
#         }#T_7cac1_row9_col3{
#             background-color:  #a8d2a8;
#             color:  #000000;
#         }#T_7cac1_row9_col5{
#             background-color:  #c9e2c8;
#             color:  #000000;
#         }#T_7cac1_row9_col7{
#             background-color:  #b3d8b3;
#             color:  #000000;
#         }#T_7cac1_row9_col9{
#             background-color:  #64b164;
#             color:  #000000;
#         }#T_7cac1_row9_col10{
#             background-color:  #b2d7b2;
#             color:  #000000;
#         }#T_7cac1_row9_col11{
#             background-color:  #b2d7b1;
#             color:  #000000;
#         }#T_7cac1_row10_col0,#T_7cac1_row10_col1,#T_7cac1_row10_col2,#T_7cac1_row10_col3,#T_7cac1_row10_col4{
#             background-color:  #e1eee1;
#             color:  #000000;
#         }#T_7cac1_row10_col5{
#             background-color:  #41a041;
#             color:  #000000;
#         }#T_7cac1_row10_col7{
#             background-color:  #3d9e3d;
#             color:  #000000;
#         }#T_7cac1_row10_col8{
#             background-color:  #4ba54b;
#             color:  #000000;
#         }#T_7cac1_row10_col9,#T_7cac1_row11_col8{
#             background-color:  #3f9f3f;
#             color:  #000000;
#         }#T_7cac1_row10_col10,#T_7cac1_row11_col10{
#             background-color:  #daebda;
#             color:  #000000;
#         }#T_7cac1_row10_col11,#T_7cac1_row11_col11{
#             background-color:  #deedde;
#             color:  #000000;
#         }#T_7cac1_row11_col0,#T_7cac1_row11_col1,#T_7cac1_row11_col2,#T_7cac1_row11_col4{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_7cac1_row11_col3{
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_7cac1_row11_col5{
#             background-color:  #369b36;
#             color:  #000000;
#         }#T_7cac1_row11_col6{
#             background-color:  #6fb76f;
#             color:  #000000;
#         }#T_7cac1_row11_col7{
#             background-color:  #349934;
#             color:  #000000;
#         }#T_7cac1_row11_col9{
#             background-color:  #359a35;
#             color:  #000000;
#         }</style><table id="T_7cac1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>        <th class="col_heading level0 col10" >10</th>        <th class="col_heading level0 col11" >11</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7cac1_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7cac1_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_7cac1_row0_col1" class="data row0 col1" >

# %%
s
# Out:
# <style  type="text/css" >
# #T_32a95_row0_col0,#T_32a95_row0_col1,#T_32a95_row0_col2,#T_32a95_row0_col3,#T_32a95_row0_col4,#T_32a95_row1_col0,#T_32a95_row1_col1,#T_32a95_row1_col2,#T_32a95_row1_col3,#T_32a95_row1_col4,#T_32a95_row2_col0,#T_32a95_row2_col1,#T_32a95_row2_col2,#T_32a95_row2_col3,#T_32a95_row2_col4,#T_32a95_row3_col0,#T_32a95_row3_col1,#T_32a95_row3_col2,#T_32a95_row3_col3,#T_32a95_row3_col4,#T_32a95_row4_col0,#T_32a95_row4_col1,#T_32a95_row4_col2,#T_32a95_row4_col3,#T_32a95_row4_col4,#T_32a95_row6_col6,#T_32a95_row7_col5,#T_32a95_row7_col7,#T_32a95_row8_col8,#T_32a95_row9_col5,#T_32a95_row9_col9,#T_32a95_row10_col10,#T_32a95_row10_col11,#T_32a95_row11_col10,#T_32a95_row11_col11{
#             background-color:  #ebf3eb;
#             color:  #000000;
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_32a95_row0_col5,#T_32a95_row0_col7,#T_32a95_row1_col7,#T_32a95_row1_col9,#T_32a95_row2_col7,#T_32a95_row2_col9,#T_32a95_row3_col7,#T_32a95_row4_col6,#T_32a95_row4_col7,#T_32a95_row4_col9,#T_32a95_row5_col8,#T_32a95_row7_col0,#T_32a95_row7_col1,#T_32a95_row7_col2,#T_32a95_row7_col3,#T_32a95_row7_col4,#T_32a95_row7_col10,#T_32a95_row7_col11{
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_32a95_row0_col6,#T_32a95_row1_col6,#T_32a95_row2_col6{
#             background-color:  #018001;
#             color:  #f1f1f1;
#             background-color:  #018001;
#             color:  #f1f1f1;
#         }#T_32a95_row0_col8,#T_32a95_row1_col8,#T_32a95_row2_col8,#T_32a95_row4_col8{
#             background-color:  #90c790;
#             color:  #000000;
#             background-color:  #90c790;
#             color:  #000000;
#         }#T_32a95_row0_col9,#T_32a95_row0_col10,#T_32a95_row1_col10,#T_32a95_row2_col10,#T_32a95_row4_col10{
#             background-color:  #a2cfa2;
#             color:  #000000;
#             background-color:  #a2cfa2;
#             color:  #000000;
#         }#T_32a95_row0_col11,#T_32a95_row1_col11,#T_32a95_row2_col11,#T_32a95_row4_col11{
#             background-color:  #b1d7b1;
#             color:  #000000;
#             background-color:  #b1d7b1;
#             color:  #000000;
#         }#T_32a95_row1_col5,#T_32a95_row2_col5,#T_32a95_row4_col5{
#             background-color:  #319831;
#             color:  #000000;
#             background-color:  #319831;
#             color:  #000000;
#         }#T_32a95_row3_col5{
#             background-color:  #329832;
#             color:  #000000;
#             background-color:  #329832;
#             color:  #000000;
#         }#T_32a95_row3_col6{
#             background-color:  #038103;
#             color:  #f1f1f1;
#             background-color:  #038103;
#             color:  #f1f1f1;
#         }#T_32a95_row3_col8{
#             background-color:  #91c791;
#             color:  #000000;
#             background-color:  #91c791;
#             color:  #000000;
#         }#T_32a95_row3_col9{
#             background-color:  #a6d1a6;
#             color:  #000000;
#             background-color:  #a6d1a6;
#             color:  #000000;
#         }#T_32a95_row3_col10{
#             background-color:  #a6d2a6;
#             color:  #000000;
#             background-color:  #a6d2a6;
#             color:  #000000;
#         }#T_32a95_row3_col11{
#             background-color:  #b6d9b6;
#             color:  #000000;
#             background-color:  #b6d9b6;
#             color:  #000000;
#         }#T_32a95_row5_col0,#T_32a95_row5_col2,#T_32a95_row5_col3,#T_32a95_row5_col4{
#             background-color:  #6cb56c;
#             color:  #000000;
#             background-color:  #6cb56c;
#             color:  #000000;
#         }#T_32a95_row5_col1{
#             background-color:  #4ba54a;
#             color:  #000000;
#             background-color:  #4ba54a;
#             color:  #000000;
#         }#T_32a95_row5_col5{
#             background-color:  #b2d7b2;
#             color:  #000000;
#             background-color:  #b2d7b2;
#             color:  #000000;
#         }#T_32a95_row5_col6,#T_32a95_row11_col0,#T_32a95_row11_col1,#T_32a95_row11_col2,#T_32a95_row11_col4{
#             background-color:  #e2efe2;
#             color:  #000000;
#             background-color:  #e2efe2;
#             color:  #000000;
#         }#T_32a95_row5_col7,#T_32a95_row6_col5{
#             background-color:  #e9f2e9;
#             color:  #000000;
#             background-color:  #e9f2e9;
#             color:  #000000;
#         }#T_32a95_row5_col9,#T_32a95_row9_col7,#T_32a95_row10_col6{
#             background-color:  #e4f0e4;
#             color:  #000000;
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_32a95_row5_col10,#T_32a95_row5_col11{
#             background-color:  #6db66d;
#             color:  #000000;
#             background-color:  #6db66d;
#             color:  #000000;
#         }#T_32a95_row6_col0,#T_32a95_row6_col2,#T_32a95_row6_col3,#T_32a95_row6_col4{
#             background-color:  #82c082;
#             color:  #000000;
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_32a95_row6_col1{
#             background-color:  #81bf81;
#             color:  #000000;
#             background-color:  #81bf81;
#             color:  #000000;
#         }#T_32a95_row6_col7,#T_32a95_row6_col11{
#             background-color:  #d9ead9;
#             color:  #000000;
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_32a95_row6_col8,#T_32a95_row11_col8{
#             background-color:  #c2dfc2;
#             color:  #000000;
#             background-color:  #c2dfc2;
#             color:  #000000;
#         }#T_32a95_row6_col9{
#             background-color:  #b3d8b3;
#             color:  #000000;
#             background-color:  #b3d8b3;
#             color:  #000000;
#         }#T_32a95_row6_col10,#T_32a95_row11_col9{
#             background-color:  #d5e9d5;
#             color:  #000000;
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_32a95_row7_col6{
#             background-color:  #c3e0c3;
#             color:  #000000;
#             background-color:  #c3e0c3;
#             color:  #000000;
#         }#T_32a95_row7_col8{
#             background-color:  #3e9e3e;
#             color:  #000000;
#             background-color:  #3e9e3e;
#             color:  #000000;
#         }#T_32a95_row7_col9{
#             background-color:  #d7e9d7;
#             color:  #000000;
#             background-color:  #d7e9d7;
#             color:  #000000;
#         }#T_32a95_row8_col0,#T_32a95_row8_col1,#T_32a95_row8_col2,#T_32a95_row8_col3,#T_32a95_row8_col4,#T_32a95_row10_col8{
#             background-color:  #c6e1c6;
#             color:  #000000;
#             background-color:  #c6e1c6;
#             color:  #000000;
#         }#T_32a95_row8_col5{
#             background-color:  #c0dec0;
#             color:  #000000;
#             background-color:  #c0dec0;
#             color:  #000000;
#         }#T_32a95_row8_col6{
#             background-color:  #c5e0c5;
#             color:  #000000;
#             background-color:  #c5e0c5;
#             color:  #000000;
#         }#T_32a95_row8_col7{
#             background-color:  #a4d0a4;
#             color:  #000000;
#             background-color:  #a4d0a4;
#             color:  #000000;
#         }#T_32a95_row8_col9{
#             background-color:  #b0d6b0;
#             color:  #000000;
#             background-color:  #b0d6b0;
#             color:  #000000;
#         }#T_32a95_row8_col10{
#             background-color:  #85c185;
#             color:  #000000;
#             background-color:  #85c185;
#             color:  #000000;
#         }#T_32a95_row8_col11{
#             background-color:  #79bc79;
#             color:  #000000;
#             background-color:  #79bc79;
#             color:  #000000;
#         }#T_32a95_row9_col0{
#             background-color:  #d1e6d1;
#             color:  #000000;
#             background-color:  #d1e6d1;
#             color:  #000000;
#         }#T_32a95_row9_col1,#T_32a95_row9_col2,#T_32a95_row9_col3,#T_32a95_row9_col4{
#             background-color:

# %%
df19j = df19[df19.date.dt.month == 7]
df19f = df19[df19.date.dt.month == 6]
qw,we,r= gmm20k(df19j.value,df19f.value)
print(qw)
print(we)
print(r)
# Out:
# [(0.03680788960154117, 0.06764230961801905), (0.009093045896577728, 0.9323576903819809), (0, 0)]
# [(0.05143587184378962, 0.0667888273364624), (0.008505409622636169, 0.29050665528132086), (0.0017537042888375552, 0.6427045173822166)]
# 0.0015167733429392338

# %%
a = np.zeros(shape=(12, 12))
for i in range(1,13):
    for j in range(1,13):
        dfc = df19[df19.date.dt.month == i]
        dfd = df19[df19.date.dt.month == j]
        _,_,r = gmm20k(dfc.value,dfd.value)
        a[i-1][j-1] = r
a
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 6.49000000e-02, 4.27960902e-02, 9.53870969e-02,
#         1.51632334e-02, 1.06940969e-02, 4.56631087e-03, 3.50548272e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 5.15985221e-02, 4.28184363e-02, 9.53870969e-02,
#         1.52422568e-02, 3.46086869e-02, 4.56631087e-03, 3.50548272e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 5.15985221e-02, 4.27960902e-02, 9.53870969e-02,
#         1.52422568e-02, 3.46086869e-02, 4.56631087e-03, 3.50548272e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 5.12563446e-02, 4.24542257e-02, 9.50440861e-02,
#         1.50240636e-02, 1.02116570e-02, 4.23617930e-03, 3.17258090e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 5.15985221e-02, 4.29903183e-02, 9.53870969e-02,
#         1.51632334e-02, 3.46086869e-02, 4.56631087e-03, 3.50548272e-03],
#        [5.15985221e-02, 6.49000000e-02, 5.15985221e-02, 5.12563446e-02,
#         5.15985221e-02, 1.63197865e-02, 1.51677334e-03, 9.85723335e-04,
#         3.94876958e-02, 1.07491283e-03, 7.79314135e-03, 7.48959612e-03],
#        [4.27960902e-02, 4.29903183e-02, 4.27960902e-02, 4.24765399e-02,
#         4.27960902e-02, 1.51677334e-03, 9.62964972e-35, 7.24901195e-03,
#         6.89635480e-03, 8.20764747e-03, 1.34274909e-03, 1.06348298e-03],
#        [9.53870969e-02, 9.53870969e-02, 9.53870969e-02, 9.50440861e-02,
#         9.53870969e-02, 9.85723335e-04, 7.24901195e-03, 0.00000000e+00,
#         2.90552280e-02, 2.92966311e-03, 1.46206286e-02, 1.40959074e-02],
#        [1.52422568e-02, 1.51632334e-02, 1.52422568e-02, 1.49456097e-02,
#         1.51632334e-02, 1.26465227e-02, 6.96977950e-03, 2.90552280e-02,
#         0.00000000e+00, 8.72952691e-03, 6.28295412e-03, 6.81827200e-03],
#        [1.04491172e-02, 3.46086869e-02, 3.46086869e-02, 3.42538523e-02,
#         3.46086869e-02, 1.07491283e-03, 5.57771009e-03, 2.92966311e-03,
#         5.09254190e-04, 0.00000000e+00, 1.27787402e-02, 1.27167190e-02],
#        [4.56631087e-03, 4.56631087e-03, 4.56631087e-03, 4.23617930e-03,
#         4.56631087e-03, 7.79314135e-03, 1.31067415e-03, 1.46206286e-02,
#         6.28295412e-03, 1.27787402e-02, 0.00000000e+00, 1.03455089e-05],
#        [3.50548272e-03, 3.50548272e-03, 3.50548272e-03, 3.17258090e-03,
#         3.50548272e-03, 4.27464144e-02, 1.02760912e-03, 1.40959074e-02,
#         6.81827200e-03, 3.15697247e-03, 1.03455089e-05, 0.00000000e+00]])

# %%
dfw = pd.DataFrame(a)
cm = sns.light_palette("green", as_cmap=True)
s = dfw.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_32a95_row0_col0,#T_32a95_row0_col1,#T_32a95_row0_col2,#T_32a95_row0_col3,#T_32a95_row0_col4,#T_32a95_row1_col0,#T_32a95_row1_col1,#T_32a95_row1_col2,#T_32a95_row1_col3,#T_32a95_row1_col4,#T_32a95_row2_col0,#T_32a95_row2_col1,#T_32a95_row2_col2,#T_32a95_row2_col3,#T_32a95_row2_col4,#T_32a95_row3_col0,#T_32a95_row3_col1,#T_32a95_row3_col2,#T_32a95_row3_col3,#T_32a95_row3_col4,#T_32a95_row4_col0,#T_32a95_row4_col1,#T_32a95_row4_col2,#T_32a95_row4_col3,#T_32a95_row4_col4,#T_32a95_row6_col6,#T_32a95_row7_col5,#T_32a95_row7_col7,#T_32a95_row8_col8,#T_32a95_row9_col5,#T_32a95_row9_col9,#T_32a95_row10_col10,#T_32a95_row10_col11,#T_32a95_row11_col10,#T_32a95_row11_col11{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_32a95_row0_col5,#T_32a95_row0_col7,#T_32a95_row1_col7,#T_32a95_row1_col9,#T_32a95_row2_col7,#T_32a95_row2_col9,#T_32a95_row3_col7,#T_32a95_row4_col6,#T_32a95_row4_col7,#T_32a95_row4_col9,#T_32a95_row5_col8,#T_32a95_row7_col0,#T_32a95_row7_col1,#T_32a95_row7_col2,#T_32a95_row7_col3,#T_32a95_row7_col4,#T_32a95_row7_col10,#T_32a95_row7_col11{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_32a95_row0_col6,#T_32a95_row1_col6,#T_32a95_row2_col6{
#             background-color:  #018001;
#             color:  #f1f1f1;
#         }#T_32a95_row0_col8,#T_32a95_row1_col8,#T_32a95_row2_col8,#T_32a95_row4_col8{
#             background-color:  #90c790;
#             color:  #000000;
#         }#T_32a95_row0_col9,#T_32a95_row0_col10,#T_32a95_row1_col10,#T_32a95_row2_col10,#T_32a95_row4_col10{
#             background-color:  #a2cfa2;
#             color:  #000000;
#         }#T_32a95_row0_col11,#T_32a95_row1_col11,#T_32a95_row2_col11,#T_32a95_row4_col11{
#             background-color:  #b1d7b1;
#             color:  #000000;
#         }#T_32a95_row1_col5,#T_32a95_row2_col5,#T_32a95_row4_col5{
#             background-color:  #319831;
#             color:  #000000;
#         }#T_32a95_row3_col5{
#             background-color:  #329832;
#             color:  #000000;
#         }#T_32a95_row3_col6{
#             background-color:  #038103;
#             color:  #f1f1f1;
#         }#T_32a95_row3_col8{
#             background-color:  #91c791;
#             color:  #000000;
#         }#T_32a95_row3_col9{
#             background-color:  #a6d1a6;
#             color:  #000000;
#         }#T_32a95_row3_col10{
#             background-color:  #a6d2a6;
#             color:  #000000;
#         }#T_32a95_row3_col11{
#             background-color:  #b6d9b6;
#             color:  #000000;
#         }#T_32a95_row5_col0,#T_32a95_row5_col2,#T_32a95_row5_col3,#T_32a95_row5_col4{
#             background-color:  #6cb56c;
#             color:  #000000;
#         }#T_32a95_row5_col1{
#             background-color:  #4ba54a;
#             color:  #000000;
#         }#T_32a95_row5_col5{
#             background-color:  #b2d7b2;
#             color:  #000000;
#         }#T_32a95_row5_col6,#T_32a95_row11_col0,#T_32a95_row11_col1,#T_32a95_row11_col2,#T_32a95_row11_col4{
#             background-color:  #e2efe2;
#             color:  #000000;
#         }#T_32a95_row5_col7,#T_32a95_row6_col5{
#             background-color:  #e9f2e9;
#             color:  #000000;
#         }#T_32a95_row5_col9,#T_32a95_row9_col7,#T_32a95_row10_col6{
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_32a95_row5_col10,#T_32a95_row5_col11{
#             background-color:  #6db66d;
#             color:  #000000;
#         }#T_32a95_row6_col0,#T_32a95_row6_col2,#T_32a95_row6_col3,#T_32a95_row6_col4{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_32a95_row6_col1{
#             background-color:  #81bf81;
#             color:  #000000;
#         }#T_32a95_row6_col7,#T_32a95_row6_col11{
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_32a95_row6_col8,#T_32a95_row11_col8{
#             background-color:  #c2dfc2;
#             color:  #000000;
#         }#T_32a95_row6_col9{
#             background-color:  #b3d8b3;
#             color:  #000000;
#         }#T_32a95_row6_col10,#T_32a95_row11_col9{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_32a95_row7_col6{
#             background-color:  #c3e0c3;
#             color:  #000000;
#         }#T_32a95_row7_col8{
#             background-color:  #3e9e3e;
#             color:  #000000;
#         }#T_32a95_row7_col9{
#             background-color:  #d7e9d7;
#             color:  #000000;
#         }#T_32a95_row8_col0,#T_32a95_row8_col1,#T_32a95_row8_col2,#T_32a95_row8_col3,#T_32a95_row8_col4,#T_32a95_row10_col8{
#             background-color:  #c6e1c6;
#             color:  #000000;
#         }#T_32a95_row8_col5{
#             background-color:  #c0dec0;
#             color:  #000000;
#         }#T_32a95_row8_col6{
#             background-color:  #c5e0c5;
#             color:  #000000;
#         }#T_32a95_row8_col7{
#             background-color:  #a4d0a4;
#             color:  #000000;
#         }#T_32a95_row8_col9{
#             background-color:  #b0d6b0;
#             color:  #000000;
#         }#T_32a95_row8_col10{
#             background-color:  #85c185;
#             color:  #000000;
#         }#T_32a95_row8_col11{
#             background-color:  #79bc79;
#             color:  #000000;
#         }#T_32a95_row9_col0{
#             background-color:  #d1e6d1;
#             color:  #000000;
#         }#T_32a95_row9_col1,#T_32a95_row9_col2,#T_32a95_row9_col3,#T_32a95_row9_col4{
#             background-color:  #96c996;
#             color:  #000000;
#         }#T_32a95_row9_col6{
#             background-color:  #cce4cc;
#             color:  #000000;
#         }#T_32a95_row9_col8{
#             background-color:  #e8f2e8;
#             color:  #000000;
#         }#T_32a95_row9_col10{
#             background-color:  #1d8e1d;
#             color:  #000000;
#         }#T_32a95_row9_col11{
#             background-color:  #178b17;
#             color:  #000000;
#         }#T_32a95_row10_col0,#T_32a95_row10_col1,#T_32a95_row10_col2,#T_32a95_row10_col4{
#             background-color:  #e0eedf;
#             color:  #000000;
#         }#T_32a95_row10_col3{
#             background-color:  #e0eee0;
#             color:  #000000;
#         }#T_32a95_row10_col5{
#             background-color:  #d2e7d2;
#             color:  #000000;
#         }#T_32a95_row10_col7{
#             background-color:  #c7e1c7;
#             color:  #000000;
#         }#T_32a95_row10_col9{
#             background-color:  #94c994;
#             color:  #000000;
#         }#T_32a95_row11_col3{
#             background-color:  #e3efe3;
#             color:  #000000;
#         }#T_32a95_row11_col5{
#             background-color:  #51a851;
#             color:  #000000;
#         }#T_32a95_row11_col6{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_32a95_row11_col7{
#             background-color:  #c9e2c8;
#             color:  #000000;
#         }</style><table id="T_32a95_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>        <th class="col_heading level0 col10" >10</th>        <th class="col_heading level0 col11" >11</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_32a95_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_32a95_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_32a95_row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_32a95_row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_32a95_row0_col3" clas

# %% [markdown]
# ## OrderbyMeans

# %%
means=[]
for i in range(len(best_gmmq1.means_)):
    means.append(best_gmmq1.means_[i][0])
x = dict(zip(means,best_gmmq1.weights_))
od1 = collections.OrderedDict(sorted(x.items(),reverse=True))
od1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d435bc4e97bd> in <module>
#       1 means=[]
# ----> 2 for i in range(len(best_gmmq1.means_)):
#       3     means.append(best_gmmq1.means_[i][0])
#       4 x = dict(zip(means,best_gmmq1.weights_))
#       5 od1 = collections.OrderedDict(sorted(x.items(),reverse=True))
#
# NameError: name 'best_gmmq1' is not defined

# %%
means=[]
for i in range(len(best_gmmq2.means_)):
    means.append(best_gmmq2.means_[i][0])
x = dict(zip(means,best_gmmq2.weights_))
od2 = collections.OrderedDict(sorted(x.items(),reverse=True))
od2

# %% [markdown]
# ## OrderbyWeights

# %%
means=[]
for i in range(len(best_gmmq1.means_)):
    means.append(best_gmmq1.means_[i][0])
x = dict(zip(best_gmmq1.weights_,means))
od1 = collections.OrderedDict(sorted(x.items(),reverse=True))
od1 = list(zip(list(od1.keys()),list(od1.values())))
od1

# %%
means=[]
for i in range(len(best_gmmq2.means_)):
    means.append(best_gmmq2.means_[i][0])
y = dict(zip(best_gmmq2.weights_,means))
od2 = collections.OrderedDict(sorted(y.items(),reverse=True))
od2 = list(zip(list(od2.keys()),list(od2.values())))
od2

# %%
thres = 0.05
diffmean = []
diffweights = []
for i in range(len(od1)):
    diffmean.append(od1[i][1] - od2[i][1])
    diffweights.append(od1[i][0] - od2[i][0])

# %%
print(diffmean)
print(diffweights)
