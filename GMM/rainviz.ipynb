# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import mixture
sns.set(style='whitegrid')
sns.set_palette('bright')
import warnings
warnings.filterwarnings('ignore')
import collections
from scipy.spatial import distance
from scipy.stats import norm
from scipy import stats
from scipy.stats import wasserstein_distance

# %%
df = pd.read_csv('preci_alt.csv')
df.columns = ['date','value']
df.date = pd.to_datetime(df.date,format='%b %d, %Y')

# %%
df2019 = df[(df.date.dt.year == 2019)]
df2018 = df[(df.date.dt.year == 2018)]
df2017 = df[(df.date.dt.year == 2017)]
df2016 = df[(df.date.dt.year == 2016)]
df2019
# Out:
#            date  value
# 3287 2019-01-01  0.000
# 3288 2019-01-02  0.000
# 3289 2019-01-03  0.000
# 3290 2019-01-04  0.000
# 3291 2019-01-05  0.000
# ...         ...    ...
# 3645 2019-12-25  0.004
# 3646 2019-12-26  0.004
# 3647 2019-12-27  0.000
# 3648 2019-12-28  0.000
# 3649 2019-12-29  0.001
#
# [363 rows x 2 columns]

# %%
df19 = df[df.date.dt.year == 2019]
fig, ax = plt.subplots(12,1, figsize=(18,25),sharey= True)
for i in range(0,12):
    dff = df19[df19.date.dt.month == i+1]
    sns.lineplot(dff.date,dff.value,ax = ax[i])
plt.show()

# %%
fig ,ax = plt.subplots(1,1,figsize=(15,5))
sns.lineplot(df19.date,df19.value)
# Out:
# <AxesSubplot:xlabel='date', ylabel='value'>

# %%
df18 = df[df.date.dt.year == 2018]
fig ,ax = plt.subplots(1,1,figsize=(15,5))
sns.lineplot(df18.date,df18.value)
# Out:
# <AxesSubplot:xlabel='date', ylabel='value'>

# %%
minn=[]
maxx=[]
means=[]
df19 = df[df.date.dt.year == 2019]
for i in range(0,12):
    dff = df19[df19.date.dt.month == i+1]
    minn.append(dff.value.min())
    maxx.append(dff.value.max())
    means.append(dff.value.mean())
dmc = pd.DataFrame(zip(minn,maxx,means),columns=['min','max','means'])
dfw = pd.DataFrame(dmc)
cm = sns.light_palette("green", as_cmap=True)
s1 = dfw.style.background_gradient(cmap=cm)
minn=[]
maxx=[]
means=[]
df19 = df[df.date.dt.year == 2018]
for i in range(0,12):
    dff = df19[df19.date.dt.month == i+1]
    minn.append(dff.value.min())
    maxx.append(dff.value.max())
    means.append(dff.value.mean())
dmc = pd.DataFrame(zip(minn,maxx,means),columns=['min','max','means'])
dfw = pd.DataFrame(dmc)
cm = sns.light_palette("green", as_cmap=True)
s2= dfw.style.background_gradient(cmap=cm)

# %%
s1
# Out:
# <style  type="text/css" >
# #T_620c4_row0_col0,#T_620c4_row0_col1,#T_620c4_row0_col2,#T_620c4_row1_col0,#T_620c4_row1_col1,#T_620c4_row1_col2,#T_620c4_row2_col0,#T_620c4_row2_col1,#T_620c4_row2_col2,#T_620c4_row3_col0,#T_620c4_row4_col0,#T_620c4_row4_col1,#T_620c4_row4_col2,#T_620c4_row5_col0,#T_620c4_row8_col0,#T_620c4_row9_col0,#T_620c4_row10_col0,#T_620c4_row11_col0{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_620c4_row3_col1,#T_620c4_row10_col2,#T_620c4_row11_col1{
#             background-color:  #e1eee1;
#             color:  #000000;
#         }#T_620c4_row3_col2{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_620c4_row5_col1{
#             background-color:  #59ac59;
#             color:  #000000;
#         }#T_620c4_row5_col2{
#             background-color:  #78bb78;
#             color:  #000000;
#         }#T_620c4_row6_col0,#T_620c4_row7_col0,#T_620c4_row7_col1,#T_620c4_row7_col2{
# ...

# %%
s2
# Out:
# <style  type="text/css" >
# #T_50e06_row0_col0,#T_50e06_row0_col1,#T_50e06_row0_col2,#T_50e06_row1_col0,#T_50e06_row1_col1,#T_50e06_row1_col2,#T_50e06_row2_col0,#T_50e06_row2_col1,#T_50e06_row2_col2,#T_50e06_row3_col0,#T_50e06_row4_col0,#T_50e06_row8_col0,#T_50e06_row9_col0,#T_50e06_row10_col0,#T_50e06_row11_col0,#T_50e06_row11_col1,#T_50e06_row11_col2{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_50e06_row3_col1,#T_50e06_row4_col1{
#             background-color:  #dfeddf;
#             color:  #000000;
#         }#T_50e06_row3_col2{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_50e06_row4_col2{
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_50e06_row5_col0,#T_50e06_row5_col1{
#             background-color:  #75b975;
#             color:  #000000;
#         }#T_50e06_row5_col2{
#             background-color:  #4ca54c;
#             color:  #000000;
# ...

# %%
minn=[]
maxx=[]
means=[]
df19 = df[df.date.dt.year == 2018]
for i in range(0,12):
    dff = df19[df19.date.dt.month == i+1]
    minn.append(dff.value.min())
    maxx.append(dff.value.max())
    means.append(dff.value.mean())
dmc = pd.DataFrame(zip(minn,maxx,means),columns=['min','max','means'])
dfw = pd.DataFrame(dmc)
cm = sns.light_palette("green", as_cmap=True)
s = dfw.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_6b0ff_row0_col0,#T_6b0ff_row0_col1,#T_6b0ff_row0_col2,#T_6b0ff_row1_col0,#T_6b0ff_row1_col1,#T_6b0ff_row1_col2,#T_6b0ff_row2_col0,#T_6b0ff_row2_col1,#T_6b0ff_row2_col2,#T_6b0ff_row3_col0,#T_6b0ff_row4_col0,#T_6b0ff_row8_col0,#T_6b0ff_row9_col0,#T_6b0ff_row10_col0,#T_6b0ff_row11_col0,#T_6b0ff_row11_col1,#T_6b0ff_row11_col2{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_6b0ff_row3_col1,#T_6b0ff_row4_col1{
#             background-color:  #dfeddf;
#             color:  #000000;
#         }#T_6b0ff_row3_col2{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_6b0ff_row4_col2{
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_6b0ff_row5_col0,#T_6b0ff_row5_col1{
#             background-color:  #75b975;
#             color:  #000000;
#         }#T_6b0ff_row5_col2{
#             background-color:  #4ca54c;
#             color:  #000000;
# ...
