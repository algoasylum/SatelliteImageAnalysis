# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import mixture
sns.set(style='whitegrid')
sns.set_palette('bright')
import warnings
warnings.filterwarnings('ignore')
import collections
from scipy.spatial import distance
from scipy.stats import norm
from scipy import stats
from scipy.stats import wasserstein_distance

# %%
value1 = np.random.normal(loc=600,scale=50,size=5000)
value2 =  np.random.normal(loc=350,scale=20,size=10000)
q1 = np.concatenate((value1,value2))
value1 = np.random.normal(loc=350,scale=50,size=5000)
value2 =  np.random.normal(loc=600,scale=20,size=10000)
q2 = np.concatenate((value1,value2))
fig = plt.subplots(1,1)
sns.distplot(q1,bins=100)
sns.distplot(q2,bins=100)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
i=30
mymeans=[]
ilist=[]
soda=[]
value1 = np.random.normal(loc=35,scale=50,size=5000)
value2 =  np.random.normal(loc=300,scale=20,size=10000)
q1 = np.concatenate((value1,value2))
for f in range(0,450,20):
    value1 = np.random.normal(loc=300,scale=50,size=5000)
    value2 =  np.random.normal(loc=f,scale=20,size=10000)
    q2 = np.concatenate((value1,value2))
    fig = plt.subplots(1,1)
    sns.distplot(q1,bins=100)
    sns.distplot(q2,bins=100)
    plt.show()
    soda.append(wasserstein_distance(q2,q1))
    ilist.append(f)

# %%
sns.lineplot(ilist,soda)

# %%
i=30
mkc = 450
mymeans=[]
ilist=[]
soda=[]
value1 = np.random.normal(loc=35,scale=50,size=5000)
value2 =  np.random.normal(loc=300,scale=20,size=10000)
q1 = np.concatenate((value1,value2))
for f in range(0,450,20):
    mkc = mkc - 20
    value1 = np.random.normal(loc=35,scale=50,size=500)
    value2 =  np.random.normal(loc=mkc,scale=20,size=1000)
    q1 = np.concatenate((value1,value2))
    value1 = np.random.normal(loc=300,scale=50,size=5000)
    value2 =  np.random.normal(loc=f,scale=20,size=10000)
    q2 = np.concatenate((value1,value2))
    fig = plt.subplots(1,1)
    sns.distplot(q1,bins=100)
    sns.distplot(q2,bins=100)
    plt.show()
    soda.append(wasserstein_distance(q2,q1))
    ilist.append(f)

# %%
print(wasserstein_distance(q2,q1))
# Out:
# 388.05511492624095

# %%
sns.lineplot(ilist,soda)

# %%
i=30
mkc = 450
mymeans=[]
ilist=[]
soda=[]
for f in range(0,450,20):
    mkc = mkc - 20
    value2 =  np.random.normal(loc=mkc,scale=20,size=1000)
    q1 = value2
    value2 =  np.random.normal(loc=f,scale=20,size=10000)
    q2 = value2
    fig = plt.subplots(1,1)
    sns.distplot(q1,bins=100)
    sns.distplot(q2,bins=100)
    plt.show()
    soda.append(wasserstein_distance(q2,q1))
    ilist.append(f)

# %%
sns.lineplot(ilist,soda)
# Out:
# <AxesSubplot:>
