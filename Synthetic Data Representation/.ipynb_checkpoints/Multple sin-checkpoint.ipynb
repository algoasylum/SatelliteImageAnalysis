# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy import fftpack
import datetime
from sklearn import mixture
import warnings
warnings.filterwarnings('ignore')
from scipy import fft
from scipy import signal
import math
from acoustics.cepstrum import complex_cepstrum
from acoustics.cepstrum import inverse_complex_cepstrum
from scipy.spatial import distance

# %%
def idft2(yr, yi):
    N, x = yr.shape[0], []
    yr = dict(yr.values)
    yi = dict(yi.values)
    for t in range(N):
        real = 0
        for (k,v),(k2,v2) in zip(yr.items(),yi.items()):
            theta1 = t * (2 * math.pi) * k
            theta2 = t * (2 * math.pi) * k2
            real += (v * math.cos(theta1)) - (v2 * math.sin(theta2))
        x.append(real/N)
    return x

# %%
#Func gives magnitude of FFT provide dataframe in Time Domain
def freq_mag(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data = pd.DataFrame(zip(f,np.abs(yf)),columns=['Freq','Ampli'])
    return fft_data

# %%
#Func gives real and imag of FFT provide dataframe in Time Domain
def freq(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data1 = pd.DataFrame(zip(f,yf.real),columns=['Freq','Ampli'])
    fft_data2 = pd.DataFrame(zip(f,yf.imag),columns=['Freq','Ampli'])
    return fft_data1,fft_data2

# %%
def log_freq(df1, df2):
    df1['Ampli'] = np.log(df1["Ampli"])
    df1['Ampli'] = df1['Ampli'].replace([np.inf, -np.inf], 0)
    df1 = df1.fillna(0)
    df2['Ampli'] = np.log(df2["Ampli"])
    df2['Ampli'] = df2['Ampli'].replace([np.inf, -np.inf], 0)
    df2 = df2.fillna(0)
    return df1, df2

# %%
from scipy import signal
import math
t = np.linspace(0, 10, 500)
s = np.sin(2*t)+np.sin(5*t) + np.sin(10*t) 
plt.plot(t, s)
plt.show()

# %%
signal_1 = pd.DataFrame(zip(t,s),columns=['Time','Value'])
signal_1
# Out:
#          Time     Value
# 0     0.00000  0.000000
# 1     0.02004  0.339164
# 2     0.04008  0.669293
# 3     0.06012  0.981680
# 4     0.08016  1.268263
# ..        ...       ...
# 495   9.91984 -0.753733
# 496   9.93988 -0.584262
# 497   9.95992 -0.374550
# 498   9.97996 -0.129613
# 499  10.00000  0.144205
#
# [500 rows x 2 columns]

# %% [markdown]
# ## Magnitude of Freq

# %%
freq_ampli_mag = freq_mag(signal_1)
plt.scatter(freq_ampli_mag['Freq'], freq_ampli_mag['Ampli'])

# %%
value = list(freq_ampli_mag['Ampli'])
ift = fft.ifft(value)
plt.plot(t,ift)
plt.show()
plt.plot(signal_1["Time"], signal_1["Value"])
plt.show()

# %% [markdown]
# ## Freq on Real and Imag

# %%
freq_ampli1,freq_ampli1i = freq(signal_1)
fig, axs = plt.subplots(1,2,figsize=(20,10))
axs[0].scatter(freq_ampli1['Freq'], freq_ampli1['Ampli'])
axs[1].scatter(freq_ampli1i['Freq'], freq_ampli1i['Ampli'])

# %%
value = idft2(freq_ampli1,freq_ampli1i)
plt.plot(value)
plt.show()
plt.plot(signal_1["Time"], signal_1["Value"])
plt.show()

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 7.558740481189834e-14

# %% [markdown]
# Recreating the pattern

# %% [markdown]
# ## Log Freq

# %%
log1, log1i = log_freq(freq_ampli1, freq_ampli1i)

# %%
fig, axs = plt.subplots(1,2,figsize=(20,10))
axs[0].scatter(log1['Freq'], log1['Ampli'])
axs[1].scatter(log1i['Freq'], log1i['Ampli'])

# %%
log1["Ampli"] = np.exp(log1["Ampli"])
log1i["Ampli"] = np.exp(log1i["Ampli"])
value = idft2(log1,log1i)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 13.172134064390724

# %% [markdown]
# ## Cepstrum

# %%
duration = signal_1.shape[0]
fs = 1.0
samples = int(fs*duration)
t = np.arange(samples) / fs
ce
#  [ 2.50913728e-01  1.93573820e+00]
#  [ 5.94335184e+00 -1.36240028e+00]
#  [ 3.95791444e+00  2.72841585e+00]
#  [ 4.67904726e+00 -6.07617623e-01]
#  [ 7.88554181e+00  6.23041504e-01]
#  [ 9.12893413e+00  2.22280123e-01]
#  [ 2.86484107e+00  1.24187920e-01]
#  [ 7.71525210e+00  1.93301286e+00]
#  [ 2.69530668e+00  9.51846768e-01]
#  [ 6.28256937e+00 -8.38277933e-03]
#  [ 1.61287406e+00  5.29609990e-01]
#  [ 1.43263003e+00  1.99631730e+00]
#  [ 1.08752261e+00 -8.80499286e-01]
#  [ 5.17938897e+00  8.24224075e-01]
#  [ 8.48346781e+00 -1.92975833e+00]
#  [ 3.81434446e+00  1.53703108e+00]
#  [ 9.83962558e+00 -9.08156479e-01]
#  [ 3.63942186e-01  1.04142281e+00]
#  [ 6.09218263e+00 -2.08588200e+00]
#  [ 9.80784315e+00 -2.15368890e-01]
#  [ 5.55014313e+00 -1.30227848e+00]
#  [ 6.62361506e+00  1.35747550e+00]
#  [ 4.39870524e+00  5.77900939e-01]
#  [ 3.41745700e+00 -1.14561574e-01]
#  [ 8.15645907e+00 -5.74139386e-01]
#  [ 5.10579051e+00 -3.50269999e-01]
#  [ 9.07968994e-01  2.91172612e-01]
#  [ 2.14764798e+00 -1.44004345e+00]
#  [ 3.57758069e+00 -9.65617213e-01]
#  [ 7.41483043e-01  1.35433123e+00]
#  [ 7.20418299e+00  1.82992860e-01]
#  [ 6.91394071e+00  9.31667417e-01]
#  [ 2.50515911e+00 -1.03242181e+00]
#  [ 8.80754057e+00 -8.02884262e-01]
#  [ 9.57903752e+00  5.73164840e-01]
#  [ 3.66554579e+00 -4.59976613e-01]
#  [ 5.01969344e-02  7.98016157e-01]
#  [ 1.26241528e+00  6.41641321e-01]
#  [ 8.36485966e+00 -7.79157893e-01]
#  [ 4.84959359e+00 -1.97860979e+00]]

# %%
z,_ = ts.sample(500)
plt.title('Actual data')
sns.lineplot(signal_1['Time'], signal_1['Value'])
plt.show()
plt.title('Values given by GMM')
sns.lineplot(z[:,0],z[:,1])
plt.show()

# %%
distance.euclidean(signal_1["Value"], z[:, 1])
# Out:
# 40.160276538887295

# %% [markdown]
# ## GMM on Real and Img Freq

# %%
freq_ampli1,freq_ampli1i = freq(signal_1)

# %%
fr = GMM_fit(freq_ampli1)                        # GMM on real part of FFT data
fi = GMM_fit(freq_ampli1i)                      # GMM on imaginary part of FFT data

# %%
print(fr, '\n')
print('WEIGHTS -', fr.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',fr.means_, '\n')
# Out:
# GaussianMixture(n_components=34)
#
# WEIGHTS - [0.08817425 0.004      0.004      0.004      0.004      0.004
#  0.004      0.004      0.0803998  0.004      0.004      0.01998647
#  0.008      0.004      0.002      0.0356257  0.04075435 0.004
#  0.09433512 0.11518295 0.04449117 0.00799998 0.03027796 0.0564954
#  0.02599028 0.004      0.0091474  0.10807215 0.0134137  0.004
#  0.03190125 0.061814   0.06993818 0.00399989]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [
#  [-3.20000000e-02  2.42162669e+02]
#  [ 3.20000000e-02 -2.42162669e+02]
#  [-3.60000000e-02  3.34719376e+00]
#  [ 4.29097690e-02  6.37097810e-01]
#  [ 3.60000000e-02 -3.34719376e+00]
#  [-3.00000000e-02 -1.71502595e+01]
#  [ 3.40000000e-02 -9.15098533e+00]
#  [ 3.00000000e-02  1.71502595e+01]
#  [-4.00000000e-03  2.32965671e+01]
#  [-1.29708665e-01 -4.85712932e-01]
#  [ 2.60000000e-02  8.36310970e+00]
#  [-3.52265008e-01 -1.09642033e-01]
#  [ 4.00000000e-03 -2.32965671e+01]
#  [ 4.36917922e-01  4.43623769e-02]
#  [-2.80000000e-02 -1.03767750e+01]
#  [ 1.50538341e-01  4.16440272e-01]
#  [ 1.10000000e-02  7.61055379e+00]
#  [-3.80000000e-02  1.44346783e+00]
#  [-1.10000000e-02 -7.61055379e+00]
#  [-4.38394029e-02 -6.86929470e-01]
#  [ 3.80000000e-02 -1.44346783e+00]
#  [-2.00000000e-02 -6.30027528e+00]
#  [-3.40000000e-02  9.15098533e+00]
#  [-2.22096710e-01 -2.58732923e-01]
#  [-1.80000000e-02 -3.96227648e+00]
#  [ 2.25247432e-07 -2.24807363e-07]
#  [ 1.80000000e-02  3.96227648e+00]
#  [-2.60000000e-02 -8.36310970e+00]
#  [ 2.20000000e-02  6.95196667e+00]
#  [-4.44987588e-01 -3.84747422e-02]
#  [-8.68821578e-02 -6.90928828e-01]
#  [ 3.35439553e-01  1.24571824e-01]
#  [ 9.34011650e-02  6.57294287e-01]
#  [-1.71078830e-01 -3.59902344e-01]
#  [ 2.02722752e-01  2.92528473e-01]
#  [-2.82137247e-01 -1.78052769e-01]]

# %%
z1,_ = fr.sample(500)
z1i,_ = fi.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].stem(freq_ampli1['Freq'], freq_ampli1['Ampli'])
#plt.show()
ax[1].stem(z1[:, 0], z1[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].scatter(freq_ampli1i['Freq'], freq_ampli1i['Ampli'])
#plt.show()
ax[1].scatter(z1i[:, 0], z1i[:, 1])
plt.show()

# %%
fr_d = pd.DataFrame(zip(z1[:,0],z1[:,1]),columns=['Freq','Ampli'])
fi_d = pd.DataFrame(zip(z1i[:,0],z1i[:,1]),columns=['Freq','Ampli'])
value = idft2(fr_d,fi_d)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"], value)
# Out:
# 26.20242301818969

# %% [markdown]
# ## GMM on Log-Freq

# %%
lr = GMM_fit(log1)                        # GMM on real part of FFT data
li = GMM_fit(log1i)

# %%
print(lr, '\n')
print('WEIGHTS -', lr.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',lr.means_, '\n')
# Out:
# GaussianMixture(covariance_type='tied', n_components=14)
#
# WEIGHTS - [0.13590559 0.004      0.004      0.10622823 0.004      0.12392076
#  0.14290584 0.002      0.004      0.10587733 0.12955403 0.12503423
#  0.10857399 0.004     ]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[-4.30345091e-01  1.00000000e+00]
#  [ 0.00000000e+00  1.36306353e+02]
#  [ 0.00000000e+00  1.75862059e+01]
#  [ 1.77019693e-01  1.00000000e+00]
#  [ 0.00000000e+00  2.60527382e+01]
#  [-1.72868771e-01  1.00000000e+00]
#  [ 4.25090661e-01  1.00000000e+00]
#  [ 0.00000000e+00  1.58725523e+01]
#  [ 0.00000000e+00  3.10921561e-02]
#  [-5.86933764e-02  1.00000000e+00]
#  [-3.00255171e-01  1.00000000e+00]
#  [ 2.92738794e-01  1.00000000e+00]
#  [ 7.24584634e-02  1.00000000e+00]
#  [ 0.00000000e+00  1.32406243e+00]]

# %%
print(li, '\n')
print('WEIGHTS -', li.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',li.means_, '\n')
# Out:
# GaussianMixture(n_components=21)
#
# WEIGHTS - [0.14436189 0.002      0.002      0.002      0.002      0.004
#  0.15189253 0.002      0.002      0.05514846 0.002      0.02251765
#  0.002      0.004      0.004      0.006      0.09397018 0.35759644
#  0.06706637 0.002      0.07144648]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[-4.17833659e-01  1.00000000e+00]
#  [-1.60000000e-02  2.37208878e+02]
#  [ 3.00000000e-02  1.71502595e+01]
#  [-6.00000000e-03  1.87987138e+02]
#  [ 8.00000000e-03  5.22547672e+01]
#  [-4.00000248e-03  8.75704755e+00]
#  [ 4.22969488e-01  5.48931497e-02]
#  [-4.00000000e-03  2.32965671e+01]
#  [-3.20000000e-02  2.42162669e+02]
#  [ 1.58510888e-01  3.93934073e-01]
#  [ 2.00000000e-02  6.30027528e+00]
#  [ 2.70403522e-02  6.46306569e-01]
#  [ 1.00000000e-02  2.71756506e+01]
#  [-9.00000000e-03  3.65473512e+00]
#  [ 1.30000000e-02  2.06035129e+01]
#  [ 1.46666650e-02  7.39102495e+00]
#  [ 3.00197752e-01  1.59318449e-01]
#  [-1.79479601e-01  1.00000000e+00]
#  [ 2.19637205e-01  2.63442826e-01]
#  [ 2.80000000e-02  1.03767750e+01]
#  [ 9.51788928e-02  6.48565986e-01]]

# %%
z2,_ = lr.sample(500)
z2i,_ = li.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].stem(log1['Freq'], log1['Ampli'])
#plt.show()
ax[1].stem(z2[:, 0], z2[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].scatter(log1i['Freq'], log1i['Ampli'])
#plt.show()
ax[1].scatter(z2i[:, 0], z2i[:, 1])
plt.show()

# %%
lr_d = pd.DataFrame(zip(z2[:,0],np.exp(z2[:,1])),columns=['Freq','Ampli'])
li_d = pd.DataFrame(zip(z2i[:,0],np.exp(z2i[:,1])),columns=['Freq','Ampli'])
value = idft2(lr_d,li_d)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 6.723764958755733e+103

# %% [markdown]
# ## GMM on Cepstrum

# %%
c1 = np.array(ceps).reshape(-1, 1)
c = GMM_fit(c1)

# %%
print(c, '\n')
print('WEIGHTS -', c.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', c.means_, '\n')
# Out:
# GaussianMixture(covariance_type='diag', n_components=3)
#
# WEIGHTS - [0.30461222 0.03171604 0.66367174]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[-0.00244204]
#  [ 0.22972266]
#  [-0.00152611]]

# %%
z3,_ = c.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].plot(t, ceps)
#plt.show()
ax[1].plot(t, z3.flatten())
plt.show()

# %%
gmm_incep = inverse_complex_cepstrum(z3, np.array(1.0))    # inverse ceps
plt.plot(signal_1['Time'], gmm_incep)

# %%
distance.euclidean(signal_1['Value'], gmm_incep)
# Out:
# 34.901086557843534
