# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy import fftpack
import datetime
from sklearn import mixture
import warnings
warnings.filterwarnings('ignore')
from scipy import fft
from scipy import signal
import math
from acoustics.cepstrum import complex_cepstrum
from acoustics.cepstrum import inverse_complex_cepstrum
from scipy.spatial import distance

# %%
def idft2(yr, yi):
    N, x = yr.shape[0], []
    yr = dict(yr.values)
    yi = dict(yi.values)
    for t in range(N):
        real = 0
        for (k,v),(k2,v2) in zip(yr.items(),yi.items()):
            theta1 = t * (2 * math.pi) * k
            theta2 = t * (2 * math.pi) * k2
            real += (v * math.cos(theta1)) - (v2 * math.sin(theta2))
        x.append(real/N)
    return x

# %%
#Func gives magnitude of FFT provide dataframe in Time Domain
def freq_mag(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data = pd.DataFrame(zip(f,np.abs(yf)),columns=['Freq','Ampli'])
    return fft_data

# %%
#Func gives real and imag of FFT provide dataframe in Time Domain
def freq(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data1 = pd.DataFrame(zip(f,yf.real),columns=['Freq','Ampli'])
    fft_data2 = pd.DataFrame(zip(f,yf.imag),columns=['Freq','Ampli'])
    return fft_data1,fft_data2

# %%
def log_freq(df1, df2):
    df1['Ampli'] = np.log(df1["Ampli"])
    df1['Ampli'] = df1['Ampli'].replace([np.inf, -np.inf], 0)
    df1 = df1.fillna(0)
    df2['Ampli'] = np.log(df2["Ampli"])
    df2['Ampli'] = df2['Ampli'].replace([np.inf, -np.inf], 0)
    df2 = df2.fillna(0)
    return df1, df2

# %%
from scipy import signal
import matplotlib.pyplot as plt
t = np.linspace(0, 1, 500)
s = signal.sawtooth(2 * np.pi * 5 * t)
plt.plot(t, s)

# %%
signal_1 = pd.DataFrame(zip(t,s),columns=['Time','Value'])
signal_1
# Out:
#          Time    Value
# 0    0.000000 -1.00000
# 1    0.002004 -0.97996
# 2    0.004008 -0.95992
# 3    0.006012 -0.93988
# 4    0.008016 -0.91984
# ..        ...      ...
# 495  0.991984  0.91984
# 496  0.993988  0.93988
# 497  0.995992  0.95992
# 498  0.997996  0.97996
# 499  1.000000 -1.00000
#
# [500 rows x 2 columns]

# %% [markdown]
# ## Magnitude of Freq

# %%
freq_ampli_mag = freq_mag(signal_1)
plt.plot(freq_ampli_mag['Freq'], freq_ampli_mag['Ampli'])

# %%
value = list(freq_ampli_mag['Ampli'])
ift = fft.ifft(value)
plt.plot(t,ift)

# %% [markdown]
# ## Freq on Real and Imag

# %%
freq_ampli1,freq_ampli1i = freq(signal_1)
fig, axs = plt.subplots(1,2,figsize=(20,10))
axs[0].plot(freq_ampli1['Freq'], freq_ampli1['Ampli'])
axs[1].plot(freq_ampli1i['Freq'], freq_ampli1i['Ampli'])

# %%
value = idft2(freq_ampli1,freq_ampli1i)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 1.1912477914836944e-13

# %% [markdown]
# Recreating the pattern

# %% [markdown]
# ## Log Freq

# %%
log1, log1i = log_freq(freq_ampli1, freq_ampli1i)

# %%
fig, axs = plt.subplots(1,2,figsize=(20,10))
axs[0].plot(log1['Freq'], log1['Ampli'])
axs[1].plot(log1i['Freq'], log1i['Ampli'])

# %%
log1["Ampli"] = np.exp(log1["Ampli"])
log1i["Ampli"] = np.exp(log1i["Ampli"])
value = idft2(log1,log1i)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 7.1950134545526225

# %% [markdown]
# ## Cepstrum

# %%
duration = signal_1.shape[0]
fs = 1.0
samples = int(fs*duration)
t = np.arange(samples) / fs
ceps, _ = complex_cepstrum(signal_1['Value'])
print(ceps)
# Out:
# [ 9.56150462e-01 -1.60680289e+00 -6.69500650e-03 -5.40341073e-01
#  -6.68761876e-03 -3.27210264e-01 -6.67723639e-03 -2.35982206e-01
#  -6.66374563e-03 -1.85387366e-01 -6.64702168e-03 -1.53261549e-01
#  -8.66393959e-03  5.39181178e-02 -8.04598448e-03  5.90708204e-02
#  -7.33567475e-03  6.51581854e-02 -6.50798715e-03  7.24445829e-02
#  -5.52790570e-03  8.13060209e-02 -4.34487144e-03  9.22957761e-02
#  -2.88306967e-03  1.06262534e-01 -1.02339217e-03  1.24577591e-01
#   1.43263735e-03  1.49609916e-01  4.84221450e-03  1.85834705e-01
#   9.91937714e-03  2.42843466e-01  1.83239201e-02  3.45604588e-01
#   3.48855065e-02  5.86469506e-01  7.89418476e-02  1.83518248e+00]

# %%
print(_)
plt.plot(t, ceps)
# Out:
# 1.0

# %%
incep = inverse_complex_cepstrum(ceps, np.array(1.0))    # inverse ceps
plt.plot(signal_1['Time'], incep)

# %%
distance.euclidean(signal_1["Value"],incep)
# Out:
# 0.17888543820000147

# %% [markdown]
# # GMM of All

# %% [markdown]
# ## GMM on Time Series

# %%
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 100)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm

# %%
ts = GMM_fit(signal_1)
print(ts, '\n')
print('WEIGHTS -', ts.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', ts.means_, '\n')
# Out:
# GaussianMixture(covariance_type='tied', n_components=23)
#
# WEIGHTS - [0.04962207 0.03905087 0.04685313 0.04016768 0.03710292 0.04648356
#  0.04386493 0.04086047 0.002      0.05161759 0.04785667 0.05023803
#  0.03665821 0.04250179 0.03042298 0.0390267  0.04618858 0.05743678
#  0.04847388 0.05443496 0.04475705 0.06103391 0.04334725]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 0.8870972  -0.12902805]
#  [ 0.37724734  0.77247336]
#  [ 0.67209659 -0.27903407]
#  [ 0.31040244  0.10402439]
#  [ 0.06145576 -0.3854424 ]
#  [ 0.97408982  0.74089817]
#  [ 0.02292835 -0.7707165 ]
#  [ 0.93214014  0.32140141]
#  [ 1.         -1.        ]
#  [ 0.48343218 -0.16567817]
#  [ 0.22480611 -0.75193889]
#  [ 0.72077251  0.20772513]
#  [ 0.13773375  0.37733754]
#  [ 0.26875422 -0.31245779]
#  [ 0.34641074  0.46410743]
#  [ 0.09969059 -0.00309414]
#  [ 0.57552378  0.75523779]
#  [ 0.42937189 -0.70628108]
#  [ 0.62578861 -0.74211385]
#  [ 0.7724032   0.72403199]
#  [ 0.53180517  0.3180517 ]
#  [ 0.8318963  -0.68103698]
#  [ 0.175653    0.75652999]]

# %%
z,_ = ts.sample(500)
plt.title('Actual data')
sns.lineplot(signal_1['Time'], signal_1['Value'])
plt.show()
plt.title('Values given by GMM')
sns.lineplot(z[:,0],z[:,1])
plt.show()

# %%
distance.euclidean(signal_1["Value"], z[:, 1])
# Out:
# 19.50346563119117

# %% [markdown]
# ## GMM on Real and Img Freq

# %%
freq_ampli1,freq_ampli1i = freq(signal_1)

# %%
fr = GMM_fit(freq_ampli1)                        # GMM on real part of FFT data
fi = GMM_fit(freq_ampli1i)                      # GMM on imaginary part of FFT data

# %%
print(fr, '\n')
print('WEIGHTS -', fr.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',fr.means_, '\n')
# Out:
# GaussianMixture(n_components=27)
#
# WEIGHTS - [0.03121247 0.03264959 0.01984647 0.01500109 0.04552116 0.04250355
#  0.04160514 0.02384709 0.03844252 0.0399663  0.01395187 0.05394097
#  0.03585509 0.03701742 0.01458243 0.04052286 0.01409159 0.08394571
#  0.12525123 0.01591112 0.02171128 0.03469026 0.03371688 0.041299
#  0.03566135 0.0367376  0.03051798]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[
#  [ 1.68024510e-02  6.54979984e-02]
#  [ 1.84584030e-01  5.84841973e+00]
#  [ 6.00000000e-02  2.55271957e+01]
#  [ 1.10000000e-01  1.26410180e+01]
#  [-1.20000000e-01 -1.12847720e+01]
#  [ 7.45766331e-02 -8.43079824e-01]
#  [-7.00000000e-02 -2.15619826e+01]
#  [ 3.65362779e-01 -1.48061794e+00]
#  [-3.06047350e-01 -1.64425323e+00]
#  [-1.14815053e-02 -2.19946069e-01]
#  [-1.91121860e-01  1.83905662e+00]
#  [ 8.00000000e-02  1.85492324e+01]
#  [ 1.00000000e-01  1.42436857e+01]
#  [ 2.21933716e-01  4.03857223e+00]
#  [-9.00000000e-02 -1.61729485e+01]
#  [-3.09153485e-01  1.84583277e+00]
#  [ 3.85491571e-01  5.90755714e-01]
#  [-2.56208654e-01 -2.83984476e+00]
#  [-1.80874287e-01 -6.05650132e+00]
#  [ 1.56541227e-01 -1.63278456e+00]
#  [ 1.20000000e-01  1.12847720e+01]
#  [-2.50200585e-01  1.97861178e+00]
#  [-4.49423182e-01 -1.93034417e-01]
#  [ 3.00231182e-01 -1.88242239e+00]
#  [ 1.56105051e-01  7.73856961e+00]
#  [-1.40000000e-01 -9.10580805e+00]
#  [-1.10000000e-01 -1.26410180e+01]
#  [ 4.60098880e-01  1.41579631e-01]
#  [-3.72123078e-01  1.42450089e+00]
#  [-1.26738920e-01  1.39361625e+00]
#  [ 3.16395198e-01  1.45551920e+00]
#  [-1.30000000e-01 -1.01195360e+01]
#  [ 1.30000000e-01  1.01195360e+01]
#  [ 2.32834130e-01 -1.96886573e+00]
#  [-3.68479008e-01 -7.45869026e-01]
#  [-5.64303706e-02  6.22285010e-01]]

# %%
z1,_ = fr.sample(500)
z1i,_ = fi.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].stem(freq_ampli1['Freq'], freq_ampli1['Ampli'])
#plt.show()
ax[1].stem(z1[:, 0], z1[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].scatter(freq_ampli1i['Freq'], freq_ampli1i['Ampli'])
#plt.show()
ax[1].scatter(z1i[:, 0], z1i[:, 1])
plt.show()

# %%
fr_d = pd.DataFrame(zip(z1[:,0],z1[:,1]),columns=['Freq','Ampli'])
fi_d = pd.DataFrame(zip(z1i[:,0],z1i[:,1]),columns=['Freq','Ampli'])
value = idft2(fr_d,fi_d)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"], value)
# Out:
# 11.559124271486676

# %% [markdown]
# ## GMM on Log-Freq

# %%
lr = GMM_fit(log1)                        # GMM on real part of FFT data
li = GMM_fit(log1i)

# %%
print(lr, '\n')
print('WEIGHTS -', lr.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',lr.means_, '\n')
# Out:
# GaussianMixture(n_components=10)
#
# WEIGHTS - [0.04751874 0.59020359 0.03965005 0.04019879 0.06851245 0.04803877
#  0.01070584 0.04458189 0.06729279 0.04329708]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 0.36423017  1.2973534 ]
#  [-0.00992007  0.99999559]
#  [-0.47519081  1.95783505]
#  [ 0.47484836  1.95694019]
#  [-0.29296125  0.51677104]
#  [-0.36620958  1.31573792]
#  [ 0.45054918  1.        ]
#  [ 0.42180173  1.74425688]
#  [ 0.29219973  0.50787821]
#  [-0.42329168  1.75347847]]

# %%
print(li, '\n')
print('WEIGHTS -', li.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',li.means_, '\n')
# Out:
# GaussianMixture(n_components=36)
#
# WEIGHTS - [0.04102535 0.002      0.002      0.002      0.002      0.002
#  0.18480539 0.002      0.00612345 0.002      0.04406339 0.002
#  0.05964323 0.00409508 0.01782055 0.002      0.05838073 0.002
#  0.03936899 0.002      0.00747136 0.002      0.01200189 0.08741979
#  0.00841633 0.04449515 0.01001307 0.002      0.0509484  0.05013746
#  0.08287207 0.0120873  0.002      0.002      0.14681107 0.00199995]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[-3.44273096e-01  1.64659561e+00]
#  [ 2.00000000e-02  7.93813217e+01]
#  [ 1.00000000e-02  1.59295842e+02]
#  [ 7.00000000e-02  2.15619826e+01]
#  [ 4.00000000e-02  3.91610125e+01]
#  [ 1.20000000e-01  1.12847720e+01]
#  [ 2.71541026e-01  1.00000000e+00]
#  [ 3.00000000e-02  5.26257133e+01]
#  [ 2.00869146e-01  4.96928150e+00]
#  [ 5.00000000e-02  3.10139876e+01]
#  [-2.41778723e-01  1.97668081e+00]
#  [ 9.00000000e-02  1.61729485e+01]
#  [-4.62494781e-01  4.61340094e-01]
#  [ 1.75410372e-01  6.37766903e+00]
#  [ 4.50402055e-01  1.87014467e-01]
#  [ 6.00000000e-02  2.55271957e+01]
#  [-1.15081336e-01  1.28410273e+00]
#  [ 8.00000000e-02  1.85492324e+01]
#  [-2.94006466e-01  1.90874648e+00]
#  [ 1.40000000e-01  9.10580805e+00]
#  [ 2.34827721e-01  3.54037351e+00]
#  [ 1.00000000e-01  1.42436857e+01]
#  [ 7.66542035e-03  5.39719578e-01]
#  [ 4.35123567e-01  1.00000000e+00]
#  [ 2.74366407e-01  2.33677055e+00]
#  [-3.97877417e-01  1.18721005e+00]
#  [ 3.20549928e-01  1.37697221e+00]
#  [ 1.10000000e-01  1.26410180e+01]
#  [-4.69263225e-02  4.94625665e-01]
#  [-1.82962087e-01  1.79760015e+00]
#  [-2.93436621e-01  1.00000001e+00]
#  [ 3.75701597e-01  6.69938674e-01]
#  [ 1.30000000e-01  1.01195360e+01]
#  [ 1.50000000e-01  8.21468397e+00]
#  [ 7.09682339e-02  1.00000000e+00]
#  [ 1.60000000e-01  7.42453677e+00]]

# %%
z2,_ = lr.sample(500)
z2i,_ = li.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].stem(log1['Freq'], log1['Ampli'])
#plt.show()
ax[1].stem(z2[:, 0], z2[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].scatter(log1i['Freq'], log1i['Ampli'])
#plt.show()
ax[1].scatter(z2i[:, 0], z2i[:, 1])
plt.show()

# %%
lr_d = pd.DataFrame(zip(z2[:,0],np.exp(z2[:,1])),columns=['Freq','Ampli'])
li_d = pd.DataFrame(zip(z2i[:,0],np.exp(z2i[:,1])),columns=['Freq','Ampli'])
value = idft2(lr_d,li_d)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 7.132055109398568e+67

# %% [markdown]
# ## GMM on Cepstrum

# %%
c1 = np.array(ceps).reshape(-1, 1)
c = GMM_fit(c1)

# %%
print(c, '\n')
print('WEIGHTS -', c.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', c.means_, '\n')
# Out:
# GaussianMixture(covariance_type='spherical', n_components=5)
#
# WEIGHTS - [0.54199294 0.002      0.37809732 0.07590973 0.002     ]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[-0.00926021]
#  [ 1.83518248]
#  [-0.0019423 ]
#  [ 0.08803725]
#  [-1.60680289]]

# %%
z3,_ = c.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].plot(t, ceps)
#plt.show()
ax[1].plot(t, z3.flatten())
plt.show()

# %%
gmm_incep = inverse_complex_cepstrum(z3, np.array(1.0))    # inverse ceps
plt.plot(signal_1['Time'], gmm_incep)

# %%
distance.euclidean(signal_1['Value'], gmm_incep)
# Out:
# 27.21626710973884
