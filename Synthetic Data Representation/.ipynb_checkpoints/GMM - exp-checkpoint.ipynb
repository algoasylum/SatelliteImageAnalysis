# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy import fftpack
import datetime
from sklearn import mixture
import warnings
warnings.filterwarnings('ignore')
from scipy import fft

# %%
import scipy.stats as stats
import math
x = np.arange(0, 250, 1)
y[0:250] = 0
y[100] = 10
plt.plot(x, y)
plt.title("Synthetic Data")
plt.show()

# %%
signal_1 = pd.DataFrame(zip(x,y),columns=['Time','Value'])

# %% [markdown]
# # GMM on actual time series

# %%
dfx = signal_1
lowest_bic = np.infty
bic = []
n_components_range = range(1, 7)
cv_types = ['spherical', 'tied', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a Gaussian mixture with EM
        gmm = mixture.GaussianMixture(n_components=n_components,
                                      covariance_type=cv_type)
        gmm.fit(dfx)
        bic.append(gmm.bic(dfx))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm

# %%
print(best_gmm, '\n')
print('WEIGHTS -', best_gmm.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', best_gmm.means_, '\n')
# Out:
# GaussianMixture(covariance_type='diag', n_components=3)
#
# WEIGHTS - [0.49407071 0.50192929 0.004     ]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 63.62216939   0.        ]
#  [184.61992904   0.        ]
#  [100.          10.        ]]

# %%
z,_ = best_gmm.sample(250)
plt.title('Actual data')
sns.lineplot(signal_1['Time'], signal_1['Value'])
#plt.show()
plt.title('Values given by GMM')
sns.lineplot(z[:,0],z[:,1])
plt.show()

# %% [markdown]
# # GMM on FFT of actual time series

# %%
def freq(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2+1]),np.abs(yf[:N//2+1])),columns=['Freq','Ampli'])
    return freq_ampli

# %%
freq_ampli1 = freq(signal_1)

# %%
plt.plot(freq_ampli1['Freq'], freq_ampli1['Ampli'])

# %%
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 7)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm
best_gmm1 = GMM_fit(freq_ampli1)

# %%
print(best_gmm1, '\n')
print('WEIGHTS -', best_gmm1.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', best_gmm1.means_, '\n')
# Out:
# GaussianMixture(n_components=6)
#
# WEIGHTS - [0.39232813 0.00793651 0.01587301 0.25583028 0.17858743 0.14944464]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[4.03047560e-01 7.05503441e-02]
#  [1.60000000e-02 1.25230627e+02]
#  [1.60000009e-02 2.60042371e+00]
#  [2.39884073e-01 9.90108866e-02]
#  [1.30329700e-01 1.75684155e-01]
#  [4.58182874e-02 5.52329845e-01]]

# %%
z1,_ = best_gmm1.sample(126)
plt.title('Actual data')
sns.lineplot(freq_ampli1['Freq'], freq_ampli1['Ampli'])
plt.show()
plt.title('Values given by GMM')
sns.lineplot(z1[:,0],z1[:,1])
plt.show()

# %%
gm = mixture.GaussianMixture(means_init = [[0.03, 125]]).fit(freq_ampli1)

# %%
print(gm, '\n')
print('WEIGHTS -', gm.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', gm.means_, '\n')
# Out:
# GaussianMixture(means_init=array([[3.00e-02, 1.25e+02]]))
#
# WEIGHTS - [1.]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[0.25       1.20209701]]

# %%
z2,_ = gm.sample(126)
plt.title('Actual data')
sns.lineplot(freq_ampli1['Freq'], freq_ampli1['Ampli'])
#plt.show()
plt.title('Values given by GMM')
sns.lineplot(z2[:,0],z2[:,1])
plt.show()
