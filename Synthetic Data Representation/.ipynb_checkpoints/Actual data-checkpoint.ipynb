# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy import fftpack
import datetime
from sklearn import mixture
import warnings
warnings.filterwarnings('ignore')
from scipy import fft
from scipy import signal
import math
from acoustics.cepstrum import complex_cepstrum
from acoustics.cepstrum import inverse_complex_cepstrum
from scipy.spatial import distance

# %%
def idft2(yr, yi):
    N, x = yr.shape[0], []
    yr = dict(yr.values)
    yi = dict(yi.values)
    for t in range(N):
        real = 0
        for (k,v),(k2,v2) in zip(yr.items(),yi.items()):
            theta1 = t * (2 * math.pi) * k
            theta2 = t * (2 * math.pi) * k2
            real += (v * math.cos(theta1)) - (v2 * math.sin(theta2))
        x.append(real/N)
    return x

# %%
#Func gives magnitude of FFT provide dataframe in Time Domain
def freq_mag(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data = pd.DataFrame(zip(f,np.abs(yf)),columns=['Freq','Ampli'])
    return fft_data

# %%
#Func gives real and imag of FFT provide dataframe in Time Domain
def freq(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data1 = pd.DataFrame(zip(f,yf.real),columns=['Freq','Ampli'])
    fft_data2 = pd.DataFrame(zip(f,yf.imag),columns=['Freq','Ampli'])
    return fft_data1,fft_data2

# %%
def log_freq(df1, df2):
    df1['Ampli'] = np.log(df1["Ampli"])
    df1['Ampli'] = df1['Ampli'].replace([np.inf, -np.inf], 0)
    df1 = df1.fillna(0)
    df2['Ampli'] = np.log(df2["Ampli"])
    df2['Ampli'] = df2['Ampli'].replace([np.inf, -np.inf], 0)
    df2 = df2.fillna(0)
    return df1, df2

# %%
df = pd.read_csv(r"C:\Users\admin\Documents\Algo Asylum\Precipitation_Analysis\preci_all.csv")
df.columns = ['Date','ddate','value','geo']
df['Date'] = df['Date'].astype(str).str[:-2].astype(str)
df['Date'].iloc[43]
df.columns
df['Date'] = pd.to_datetime(df['Date'],format='%Y%m%d%H%M')
del df['ddate'],df['geo']
#plt.show()
sd = df.loc[(df['Date'].between('2020-06-01 00:00:00', '2020-06-30 11:30:00', inclusive=True))]
#sd['Date'] = pd.to_datetime(sd['Date'])
#y['date'] = y.groupby(y['date'].dt.date).sum()
#sd = sd.iloc[:, 1:]
s = sd['value']
t = sd['Date']
plt.figure(figsize=(10,6))
plt.plot(t, s)
plt.title("Data")
# Out:
# Text(0.5, 1.0, 'Data')

# %%
tf = np.arange(sd.shape[0])
signal_1 = pd.DataFrame(zip(tf,s),columns=['Time','Value'])
signal_1
# Out:
#       Time     Value
# 0        0  1.117254
# 1        1  0.990346
# 2        2  0.496010
# 3        3  0.468046
# 4        4  0.176660
# ...    ...       ...
# 1411  1411  0.314697
# 1412  1412  0.641172
# 1413  1413  0.531316
# 1414  1414  0.677021
# 1415  1415  0.757773
#
# [1416 rows x 2 columns]

# %% [markdown]
# ## Magnitude of Freq

# %%
freq_ampli_mag = freq_mag(signal_1)
plt.title("FFT-Magnitude")
plt.plot(freq_ampli_mag['Freq'], freq_ampli_mag['Ampli'])

# %%
value = list(freq_ampli_mag['Ampli'])
ift = fft.ifft(value)
plt.plot(t,ift)

# %% [markdown]
# ## Freq on Real and Imag

# %%
freq_ampli1,freq_ampli1i = freq(signal_1)
fig, axs = plt.subplots(1,2,figsize=(20,10))
axs[0].scatter(freq_ampli1['Freq'], freq_ampli1['Ampli'])
axs[0].title.set_text("Real part of FFT")
axs[1].scatter(freq_ampli1i['Freq'], freq_ampli1i['Ampli'])
axs[1].title.set_text("Imaginary part of FFT")

# %%
value = idft2(freq_ampli1,freq_ampli1i)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 2.476516155652981e-12

# %% [markdown]
# Recreating the pattern

# %% [markdown]
# ## Log Freq

# %%
log1, log1i = log_freq(freq_ampli1, freq_ampli1i)

# %%
fig, axs = plt.subplots(1,2,figsize=(20,10))
axs[0].plot(log1['Freq'], log1['Ampli'])
axs[0].title.set_text("Log of Real FFT")
axs[1].plot(log1i['Freq'], log1i['Ampli'])
axs[1].title.set_text("Log of Imaginary FFT")

# %%
log1["Ampli"] = np.exp(log1["Ampli"])
log1i["Ampli"] = np.exp(log1i["Ampli"])
value = idft2(log1,log1i)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 27.51407258694345

# %% [markdown]
# # FFT - Mag and Phase

# %%
#Func gives magnitude of FFT provide dataframe in Time Domain
def freq_mag(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data = pd.DataFrame(zip(f,np.abs(yf)),columns=['Freq','Ampli'])
    return fft_data

# %%
def freq_phase(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data1 = pd.DataFrame(zip(f,np.angle(yf)),columns=['Freq','Phase'])
    return fft_data1

# %%
freq_ampli_mag1 = freq_mag(signal_1)
freq_ampli_phase1 = freq_phase(signal_1)
fig, axs = plt.subplots(1,2,figsize=(20,8))
axs[0].stem(freq_ampli_mag1['Freq'], freq_ampli_mag1['Ampli'])
axs[0].set_xlim(-0.1, 0.1)
axs[0].title.set_text("FFT-Magnitude")
axs[1].stem(freq_ampli_phase1['Freq'], freq_ampli_phase1['Phase'])
axs[1].title.set_text("FFT-Phase")

# %% [markdown]
# ## Cepstrum

# %%
duration = signal_1.shape[0]
fs = 1.0
samples = int(fs*duration)
t = np.arange(samples) / fs
ceps, _ = complex_cepstrum(signal_1['Value'])
print(ceps)
# Out:
# [  2.87916508  14.74987267   2.21072865 ...  -3.02309675  -1.86010271
#  -13.8563364 ]

# %%
print(_)
plt.figure(figsize=(12,6))
plt.title("Cepstrum")
plt.xlabel("Quefrency")
plt.plot(t, ceps)
# Out:
# 14.0

# %%
incep = inverse_complex_cepstrum(ceps, np.array(14.0))    # inverse ceps
plt.plot(signal_1['Time'], incep)

# %%
distance.euclidean(signal_1["Value"],incep)
# Out:
# 5.476768876773515e-13

# %% [markdown]
# # GMM of All

# %% [markdown]
# ## GMM on Time Series

# %%
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 100)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm

# %%
ts = GMM_fit(signal_1)
print(ts, '\n')
print('WEIGHTS -', ts.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', ts.means_, '\n')
# Out:
# GaussianMixture(covariance_type='diag', n_components=20)
#
# WEIGHTS - [0.01442709 0.00352933 0.0134815  0.03275809 0.02839552 0.019615
#  0.13587153 0.0861893  0.01349782 0.03093214 0.23005458 0.03019896
#  0.07126817 0.0300965  0.01210252 0.02633945 0.06506839 0.03338327
#  0.06434974 0.05844109]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[1.37332903e+03 5.66954057e-01]
#  [4.68999635e+02 2.77922598e+00]
#  [8.37697712e+02 3.66833010e-01]
#  [1.26978822e+02 3.73351430e+00]
#  [1.23237976e+03 9.64034460e-03]
#  [7.80458546e+02 1.07880284e+00]
#  [4.46407284e+02 3.88843338e-04]
#  [2.56303406e+02 2.48525277e-04]
#  [6.40035726e+02 2.33105234e+00]
#  [1.26589003e+03 9.15158813e-02]
#  [1.07169238e+03 1.85421121e-04]
#  [7.19418960e+02 3.93012367e-01]
#  [5.08834525e+01 1.35903331e+00]
#  [5.09926520e+02 3.75602567e-01]
#  [1.47378062e+02 1.48717335e-01]
#  [1.20045319e+03 1.41023621e+00]
#  [4.73117434e+02 9.24701401e-03]
#  [1.32570218e+03 3.61502948e+00]
#  [8.06403071e+02 4.88382402e-02]
#  [7.21283250e+02 1.65897636e-01]]

# %%
z,_ = ts.sample(signal_1.shape[0])
plt.title('Actual data')
sns.lineplot(signal_1['Time'], signal_1['Value'])
plt.show()
plt.title('Values given by GMM')
sns.lineplot(z[:,0],z[:,1])
plt.show()

# %%
distance.euclidean(signal_1["Value"], z[:, 1])
# Out:
# 64.71697317106974

# %% [markdown]
# ## GMM on Real and Img Freq

# %%
freq_ampli1,freq_ampli1i = freq(signal_1)

# %%
fr = GMM_fit(freq_ampli1)                        # GMM on real part of FFT data
fi = GMM_fit(freq_ampli1i)                      # GMM on imaginary part of FFT data

# %%
print(fr, '\n')
print('WEIGHTS -', fr.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',fr.means_, '\n')
# Out:
# GaussianMixture(covariance_type='tied', n_components=22)
#
# WEIGHTS - [0.20977977 0.00282486 0.01676891 0.00762229 0.00070621 0.06232289
#  0.00773412 0.04166655 0.05157504 0.00282486 0.02250554 0.00427316
#  0.02739978 0.10685666 0.07272723 0.08606268 0.01003366 0.00425083
#  0.04637322 0.03681922 0.17221553 0.00665698]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 3.60299946e-01  2.05835262e+00]
#  [ 0.00000000e+00  3.63927616e+02]
#  [ 1.45909352e-03 -5.30915578e+01]
#  [-3.68786607e-04  7.54798814e+01]
#  [ 0.00000000e+00  6.99755243e+02]
#  [-1.59875864e-01 -1.59566359e+01]
#  [ 5.68622132e-05 -1.06195525e+02]
#  [ 8.47050728e-03  3.70309518e+01]
#  [-5.03075238e-02  5.61360164e+00]
#  [-1.54390389e-16  1.43336786e+02]
#  [-1.20933196e-02 -3.51668403e+01]
#  [ 1.05948540e-04 -1.50786980e+02]
#  [-1.93582447e-03  5.60892838e+01]
#  [-3.48574300e-01 -6.16135583e+00]
#  [ 1.78878040e-01  1.54130911e+01]
#  [ 2.85688985e-01 -9.95289950e+00]
#  [ 1.12079439e-03 -7.91739296e+01]
#  [-7.93467290e-05 -1.30460706e+02]
#  [-1.73350437e-01  1.97769674e+01]
#  [ 1.34327406e-01 -1.96085343e+01]
#  [-3.52512971e-01  4.29514981e+00]
#  [ 1.92624932e-03 -3.54986183e+01]]

# %%
print(fi, '\n')
print('WEIGHTS -', fi.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',fi.means_, '\n')
# Out:
# GaussianMixture(n_components=4)
#
# WEIGHTS - [0.36654832 0.36326913 0.13560032 0.13458223]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ -0.31191      0.60487905]
#  [  0.3130324   -0.60645329]
#  [ -0.07167612  20.7502069 ]
#  [  0.07416489 -20.91766852]]

# %%
z1,_ = fr.sample(freq_ampli1.shape[0])
z1i,_ = fi.sample(freq_ampli1i.shape[0])

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].stem(freq_ampli1['Freq'], freq_ampli1['Ampli'])
#plt.show()
ax[1].stem(z1[:, 0], z1[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].scatter(freq_ampli1i['Freq'], freq_ampli1i['Ampli'])
#plt.show()
ax[1].scatter(z1i[:, 0], z1i[:, 1])
plt.show()

# %%
fr_d = pd.DataFrame(zip(z1[:,0],z1[:,1]),columns=['Freq','Ampli'])
fi_d = pd.DataFrame(zip(z1i[:,0],z1i[:,1]),columns=['Freq','Ampli'])
value = idft2(fr_d,fi_d)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"], value)
# Out:
# 61.669833528710846

# %% [markdown]
# ## GMM on Log-Freq

# %%
lr = GMM_fit(log1)                        # GMM on real part of FFT data
li = GMM_fit(log1i)

# %%
print(lr, '\n')
print('WEIGHTS -', lr.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',lr.means_, '\n')
# Out:
# GaussianMixture(covariance_type='diag', n_components=9)
#
# WEIGHTS - [0.46181815 0.00070621 0.00282486 0.03257577 0.00282486 0.04242544
#  0.12912906 0.08142397 0.24627167]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 1.76837196e-08  1.00000000e+00]
#  [ 0.00000000e+00  6.99755243e+02]
#  [ 0.00000000e+00  3.63927616e+02]
#  [-8.93635325e-06  3.65922111e+01]
#  [-6.93889390e-18  1.43336786e+02]
#  [ 1.32748273e-07  5.75615969e+01]
#  [-2.58147482e-03  1.15727674e+01]
#  [ 3.03263672e-04  2.17742367e+01]
#  [-1.79393556e-04  4.05657345e+00]]

# %%
print(li, '\n')
print('WEIGHTS -', li.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',li.means_, '\n')
# Out:
# GaussianMixture(covariance_type='diag', n_components=6)
#
# WEIGHTS - [0.50137084 0.01044624 0.04548159 0.07260295 0.01557518 0.3545232 ]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 1.31279759e-02  1.00000463e+00]
#  [ 1.10671305e-03  1.54537468e+02]
#  [ 1.67129298e-03  4.15693087e+01]
#  [ 1.61174314e-03  2.32795044e+01]
#  [-6.39615827e-03  8.06446348e+01]
#  [-1.98578307e-02  7.36256594e+00]]

# %%
z2,_ = lr.sample(log1.shape[0])
z2i,_ = li.sample(log1i.shape[0])

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].stem(log1['Freq'], log1['Ampli'])
#plt.show()
ax[1].stem(z2[:, 0], z2[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].scatter(log1i['Freq'], log1i['Ampli'])
#plt.show()
ax[1].scatter(z2i[:, 0], z2i[:, 1])
plt.show()

# %%
lr_d = pd.DataFrame(zip(z2[:,0],np.exp(z2[:,1])),columns=['Freq','Ampli'])
li_d = pd.DataFrame(zip(z2i[:,0],np.exp(z2i[:,1])),columns=['Freq','Ampli'])
value = idft2(lr_d,li_d)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 1.0014448452070493e+160

# %% [markdown]
# ## GMM on Cepstrum

# %%
c1 = np.array(ceps).reshape(-1, 1)
c = GMM_fit(c1)

# %%
print(c, '\n')
print('WEIGHTS -', c.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', c.means_, '\n')
# Out:
# GaussianMixture(n_components=5)
#
# WEIGHTS - [8.33004199e-01 7.06214689e-04 7.06214689e-04 2.95246028e-02
#  1.36058769e-01]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 2.94351846e-04]
#  [-1.38563364e+01]
#  [ 1.47498727e+01]
#  [ 9.34736735e-02]
#  [ 7.27791634e-03]]

# %%
z3,_ = c.sample(t.shape[0])

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].plot(t, ceps)
#plt.show()
ax[1].plot(t, z3.flatten())
plt.show()

# %%
gmm_incep = inverse_complex_cepstrum(z3, np.array(14.0))    # inverse ceps
plt.plot(signal_1['Time'], gmm_incep)

# %%
distance.euclidean(signal_1['Value'], gmm_incep)
# Out:
# 61.01288937111511
