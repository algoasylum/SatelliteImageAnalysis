# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy import fftpack
import datetime
from sklearn import mixture
import warnings
warnings.filterwarnings('ignore')
from scipy import fft
from scipy.stats import wasserstein_distance

# %%
from scipy import signal
import math
x = np.linspace(0, 10, 250)
y = np.sin(2*x)+np.sin(5*x) + np.sin(10*x) 
plt.plot(x, y)
plt.show()

# %%
#x = np.arange(1, 31, 1)
signal_3 = pd.DataFrame(zip(x,y),columns=['Time','Value'])

# %% [markdown]
# # GMM on actual time series

# %%
dfx = signal_3
lowest_bic = np.infty
bic = []
n_components_range = range(1, 50)
cv_types = ['spherical', 'tied', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a Gaussian mixture with EM
        gmm = mixture.GaussianMixture(n_components=n_components,
                                      covariance_type=cv_type)
        gmm.fit(dfx)
        bic.append(gmm.bic(dfx))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm

# %%
print(best_gmm, '\n')
print('WEIGHTS -', best_gmm.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', best_gmm.means_, '\n')
# Out:
# GaussianMixture(covariance_type='tied', n_components=22)
#
# WEIGHTS - [0.05098057 0.05158298 0.06031127 0.03686717 0.05052397 0.03878405
#  0.05145948 0.05151992 0.06224783 0.03720762 0.03668296 0.03414875
#  0.0391478  0.0619064  0.04158073 0.03491336 0.06050605 0.0387192
#  0.03399225 0.05090152 0.03640674 0.03960937]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 6.93037597  0.90248603]
#  [ 1.88008119 -0.54719539]
#  [ 9.1126748   0.12177359]
#  [ 4.84957941 -1.43412888]
#  [ 0.64693628  0.90815098]
#  [ 3.95440245  2.1009376 ]
#  [ 4.40607384  0.53736266]
#  [ 8.16010597 -0.53679619]
#  [ 2.82718137  0.10095649]
#  [ 2.32442326 -2.15065157]
#  [ 7.71717891  1.44054559]
#  [ 7.36004697 -0.41970282]
#  [ 6.48754576  1.4859905 ]
#  [ 3.44549107 -0.1181038 ]
#  [ 0.19497305  1.3926896 ]
#  [ 1.07888482 -0.39751154]
#  [ 9.71327149 -0.14736602]
#  [ 8.61185745 -2.10086783]
#  [ 5.20677888  0.42298119]
#  [ 5.63542281 -0.90266583]
#  [ 1.43803011  1.44453727]
#  [ 6.08005939 -1.47057732]]

# %%
z,_ = best_gmm.sample(250)
plt.title('Actual data')
sns.lineplot(signal_3['Time'], signal_3['Value'])
#plt.show()
plt.title('Values given by GMM')
sns.lineplot(z[:,0],z[:,1])
plt.show()

# %%
from scipy.stats import wasserstein_distance
wasserstein_distance(signal_3['Value'], z[:, 1])
# Out:
# 0.13107056949850637

# %% [markdown]
# # GMM on abs FFT

# %%
def freq(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data = pd.DataFrame(zip(np.abs(f[:N//2+1]),np.abs(yf[:N//2+1])),columns=['Freq','Ampli'])
    return fft_data

# %%
freq_ampli = freq(signal_3)

# %%
#plt.figure(figsize=(10,6))
sns.lineplot(freq_ampli['Freq'], freq_ampli['Ampli'])
#plt.xlim(-0.1, 0.1)
# Out:
# <AxesSubplot:xlabel='Freq', ylabel='Ampli'>

# %%
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 50)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm
best_gmm1 = GMM_fit(freq_ampli)

# %%
print(best_gmm1, '\n')
print('WEIGHTS -', best_gmm1.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', best_gmm1.means_, '\n')
# Out:
# GaussianMixture(n_components=19)
#
# WEIGHTS - [0.16595332 0.00793651 0.00793651 0.00793651 0.00793651 0.00793651
#  0.00793651 0.00793651 0.00793651 0.03916989 0.04761905 0.00793651
#  0.11613405 0.18701676 0.13939304 0.11869984 0.00793651 0.00793651
#  0.09871246]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[3.65940456e-01 4.27462476e-01]
#  [3.20000000e-02 1.19361205e+02]
#  [2.00000000e-02 1.44554527e+01]
#  [1.60000000e-02 3.02067484e+01]
#  [6.00000000e-02 4.93115113e+00]
#  [4.00000000e-03 9.71718527e+00]
#  [6.40000000e-02 1.22844675e+02]
#  [8.00000000e-03 1.78741136e+01]
#  [1.20000000e-02 1.15708392e+02]
#  [7.59062332e-02 1.10169137e+00]
#  [4.60000000e-02 3.81221873e+00]
#  [2.80000000e-02 8.51952784e+00]
#  [2.24592865e-01 5.98564541e-01]
#  [4.54803385e-01 3.94315856e-01]
#  [2.88992503e-01 4.94138917e-01]
#  [1.15689176e-01 1.04479133e+00]
#  [0.00000000e+00 7.94960663e+00]
#  [2.40000000e-02 1.00846530e+01]
#  [1.70451654e-01 7.54708138e-01]]

# %%
z2,_ = best_gmm1.sample(126)
plt.title('Actual data')
sns.lineplot(freq_ampli['Freq'], freq_ampli['Ampli'])
#plt.show()
plt.title('Values given by GMM')
sns.lineplot(z2[:,0],z2[:,1])
plt.show()

# %%
wasserstein_distance(freq_ampli['Ampli'], z2[:, 1])
# Out:
# 4.372517044292181

# %% [markdown]
# # GMM on FFT of actual time series

# %%
def freq(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    freq_ampli_real = pd.DataFrame(zip(f[:N//2+1],yf[:N//2+1].real),columns=['Freq','Ampli'])
    freq_ampli_img = pd.DataFrame(zip(f[:N//2+1],yf[:N//2+1].imag),columns=['Freq','Ampli'])
    return freq_ampli_real,freq_ampli_img
freq_ampli3,freq_ampli3i = freq(signal_3)

# %%
plt.scatter(freq_ampli3['Freq'], freq_ampli3['Ampli'])
plt.title('Real values of FFT')
plt.show()
plt.scatter(freq_ampli3i['Freq'], freq_ampli3i['Ampli'])
plt.title('Imaginary values of FFT')
plt.show()

# %%
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 50)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm

# %%
best_gmm0 = GMM_fit(freq_ampli3)                        # GMM on real part of FFT data
best_gmm0i = GMM_fit(freq_ampli3i)                      # GMM on imaginary part of FFT data

# %%
print(best_gmm0, '\n')
print('WEIGHTS -', best_gmm0.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',best_gmm0.means_, '\n


# %%
value = list(sd.values())

# %% [markdown]
# # Final IFFT

# %%
ift = fft.ifft(value)
plt.title('IFFT')
plt.plot(signal_3['Time'], signal_3['Value'])
plt.plot(x,ift)

# %% [markdown]
# # Log frequency

# %%
log_ampli = np.log(freq_ampli["Ampli"])
log_freq_ampli= pd.DataFrame(zip(freq_ampli['Freq'],log_ampli),columns=['Freq','Ampli'])
log_freq_ampli = log_freq_ampli.loc[log_freq_ampli['Ampli'] != float('-inf')]

# %%
sns.lineplot(log_freq_ampli['Freq'], log_freq_ampli['Ampli'])
# Out:
# <AxesSubplot:xlabel='Freq', ylabel='Ampli'>

# %%
dfx = log_freq_ampli
lowest_bic = np.infty
bic = []
n_components_range = range(1, 50)
cv_types = ['spherical', 'tied', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a Gaussian mixture with EM
        gmm = mixture.GaussianMixture(n_components=n_components,
                                      covariance_type=cv_type)
        gmm.fit(dfx)
        bic.append(gmm.bic(dfx))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm2 = gmm

# %%
print(best_gmm2, '\n')
print('WEIGHTS -', best_gmm2.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', best_gmm2.means_, '\n')
# Out:
# GaussianMixture(n_components=12)
#
# WEIGHTS - [0.13484829 0.03174604 0.02380952 0.03988272 0.05555556 0.14849851
#  0.15484819 0.01587301 0.11808969 0.00793651 0.12578831 0.14312366]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 0.32102923 -0.7765113 ]
#  [ 0.014       2.20009869]
#  [ 0.036       4.78138272]
#  [ 0.0760641   0.0933668 ]
#  [ 0.048       1.37429052]
#  [ 0.4645281  -0.93593937]
#  [ 0.12519289 -0.02094986]
#  [ 0.014       2.77721267]
#  [ 0.19390021 -0.39290847]
#  [ 0.016       3.40806536]
#  [ 0.25535512 -0.61588738]
#  [ 0.39107948 -0.88288277]]

# %%
z2,_ = best_gmm2.sample(126)
plt.title('Actual data')
sns.lineplot(log_freq_ampli['Freq'], log_freq_ampli['Ampli'])
#plt.show()
plt.title('Values given by GMM')
sns.lineplot(z2[:,0],z2[:,1])
plt.show()

# %%
wasserstein_distance(log_freq_ampli['Ampli'], z2[:, 1])
# Out:
# 0.11389357495940913

# %%
def dim(df):
    d = []
    for i,j in df.values.tolist():
        for k in range(round(j)):
            d.append(i)
    return d
list(np.array(log_freq_ampli))
fre = dim(log_freq_ampli)
log_freq_ampli.sort_values(by=['Ampli'],ascending = False)
np.shape(fre)
# Out:
# (40,)

# %%
sns.lineplot(log_freq_ampli['Freq'], log_freq_ampli['Ampli'])
plt.show()
sns.distplot(fre)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
fre = np.array(fre).reshape(-1,1)
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 21)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm
best_gmm11 = GMM_fit(fre)

# %%
print(best_gmm11, '\n')
print('WEIGHTS -', best_gmm11.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', best_gmm11.means_, '\n')
# Out:
# GaussianMixture(n_components=2)
#
# WEIGHTS - [0.8096621 0.1903379]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[0.02181354]
#  [0.06219678]]

# %%
z11,_ = best_gmm11.sample(40)
plt.title('Actual data')
sns.distplot(fre)
#plt.show()
plt.title('Values given by GMM')
sns.distplot(z11)
plt.show()

# %%
wasserstein_distance(fre.flatten(), z11.flatten())
# Out:
# 0.0026659288442664104

# %% [markdown]
# # Cepstrum

# %%
frame_size = signal_3.shape[0]
Fs = 1
dt = 1/Fs
freq_vector = np.fft.rfftfreq(frame_size, d=dt)

# %%
y = np.array(signal_3['Value'])
yf = fftpack.fft(y)
yf1 = yf[yf != 0]

# %%
quefrency = np.fft.rfftfreq(np.log(yf1).size,freq_vector[1] - freq_vector[0])
cepstrum = np.fft.rfft(np.log(np.abs(yf1)))

# %%
cep = pd.DataFrame(zip(quefrency,cepstrum.real),columns=['Quefrency','Cepstrum'])
cep = cep.iloc[1:,:]
plt.plot(cep.Quefrency,cep.Cepstrum)

# %%
dfx = cep
lowest_bic = np.infty
bic = []
n_components_range = range(1, 50)
cv_types = ['spherical', 'tied', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a Gaussian mixture with EM
        gmm = mixture.GaussianMixture(n_components=n_components,
                                      covariance_type=cv_type)
        gmm.fit(dfx)
        bic.append(gmm.bic(dfx))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm3 = gmm

# %%
print(best_gmm3, '\n')
print('WEIGHTS -', best_gmm3.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', best_gmm3.means_, '\n')
# Out:
# GaussianMixture(n_components=15)
#
# WEIGHTS - [0.05599078 0.04802878 0.02399852 0.14590263 0.17433879 0.008
#  0.07679933 0.06407028 0.05641284 0.06209892 0.016      0.06924069
#  0.07155798 0.07200924 0.05555126]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[112.99950412  -5.01499872]
#  [ 51.49779229  -6.88552855]
#  [  4.99993823  34.21199223]
#  [ 15.63108198  -1.09875842]
#  [ 82.06602628   0.73046194]
#  [  1.         146.0516102 ]
#  [ 97.70487577   4.86299143]
#  [ 58.50549301   1.07655978]
#  [ 36.02927283  -2.47039992]
#  [ 28.589796    -1.92837899]
#  [  2.5         71.47448641]
#  [ 66.87997517   5.53297946]
#  [ 44.02149767  -9.04173239]
#  [120.99935874   1.27770281]
#  [106.02421639  -3.83481749]]

# %%
z3,_ = best_gmm3.sample(500)
plt.title('Actual data')
sns.lineplot(cep['Quefrency'], cep['Cepstrum'])
#plt.show()
plt.title('Values given by GMM')
sns.lineplot(z3[:,0],z3[:,1])
plt.show()

# %%
from scipy.stats import wasserstein_distance
wasserstein_distance(cep['Cepstrum'], z3[:, 1])
# Out:
# 2.3251245407921335

# %%
sns.distplot(cep['Cepstrum'], kde = True)
sns.distplot(z3[:, 1], kde = True)
plt.show()

# %%
def dim(df):
    d = []
    for i,j in df.values.tolist():
        for k in range(round(j)):
            d.append(i)
    return d
list(np.array(cep))
c = dim(cep)
cep.sort_values(by=['Cepstrum'],ascending = False)
np.shape(c)
# Out:
# (730,)

# %%
sns.lineplot(cep['Quefrency'], cep['Cepstrum'])
plt.show()
sns.distplot(c)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
c = np.array(c).reshape(-1,1)
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 100)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm
best_gmm22 = GMM_fit(c)

# %%
print(best_gmm22, '\n')
print('WEIGHTS -', best_gmm22.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', best_gmm22.means_, '\n')
# Out:
# GaussianMixture(covariance_type='tied', n_components=52)
#
# WEIGHTS - [0.00410959 0.00821918 0.08219178 0.02054795 0.01232877 0.00547945
#  0.00547945 0.01643836 0.02054795 0.2        0.01232877 0.0109589
#  0.02054795 0.00136986 0.04657534 0.00684932 0.01369863 0.11369863
#  0.00684932 0.02054795 0.06164384 0.03287671 0.01780822 0.01506849
#  0.0109589  0.01917808 0.00958904 0.02191781 0.02054795 0.01643836
#  0.01506849 0.01780822 0.00410959 0.0109589  0.00684932 0.00547945
#  0.00684932 0.01369863 0.01232877 0.00821918 0.00821918 0.00547945
#  0.00410959 0.00547945 0.00273973 0.00410959 0.00273973 0.00273973
#  0.00273973 0.00273973 0.00136986 0.00136986]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 35.]
#  [ 90.]
#  [  3.]
#  [ 64.]
#  [123.]
#  [ 80.]
#  [ 16.]
#  [ 96.]
#  [  7.]
#  [  1.]
#  [ 32.]
#  [ 60.]
#  [ 93.]
#  [109.]
#  [  5.]
#  [ 78.]
#  [ 66.]
#  [  2.]
#  [ 98.]
#  [ 63.]
#  [  4.]
#  [  6.]
#  [ 92.]
#  [125.]
#  [  8.]
#  [ 62.]
#  [ 31.]
#  [ 94.]
#  [ 95.]
#  [ 61.]
#  [124.]
#  [ 65.]
#  [ 18.]
#  [ 33.]
#  [122.]
#  [ 77.]
#  [ 79.]
#  [ 91.]
#  [ 97.]
#  [ 67.]
#  [ 34.]
#  [ 17.]
#  [ 15.]
#  [ 30.]
#  [ 89.]
#  [ 59.]
#  [ 76.]
#  [  9.]
#  [121.]
#  [ 81.]
#  [ 68.]
#  [ 14.]]

# %%
z22,_ = best_gmm22.sample(740)
plt.title('Actual data')
sns.distplot(c)
#plt.show()
plt.title('Values given by GMM')
sns.distplot(z22)
plt.show()

# %%
wasserstein_distance(c.flatten(), z22.flatten())
# Out:
# 1.1783378024420887
