# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy import fftpack
import datetime
from sklearn import mixture
import warnings
warnings.filterwarnings('ignore')

# %%
# SIGNAL 1
x1 = np.arange(0, 31)
y1 = np.zeros(31)
value = 100
y1[0] = 100
for i in range (1, 31):
    if i%7 != 0:
        y1[i] = value
    else:
        value = abs(value-100)
        y1[i] = value
plt.figure(figsize=(10,6))
plt.plot(x1, y1)
plt.title("Synthetic Data")
plt.show()

# %%
# SIGNAL 2
x2 = np.arange(0, 31)
y2 = np.zeros(31)
value = 100
y2[0] = 100
for i in range(1,31):
    if i%3 !=0:
        y2[i] = value
    else:
        value = abs(value-100)
        y2[i] = value
plt.figure(figsize=(10,6))
plt.plot(x2, y2)
plt.title("Synthetic Data")
plt.show()

# %%
signal_1 = pd.DataFrame(zip(x1,y1),columns=['Time','Value'])
signal_2 = pd.DataFrame(zip(x2,y2),columns=['Time','Value'])
signal_1.describe()
# Out:
#             Time       Value
# count  31.000000   31.000000
# mean   15.000000   54.838710
# std     9.092121   50.587941
# min     0.000000    0.000000
# 25%     7.500000    0.000000
# 50%    15.000000  100.000000
# 75%    22.500000  100.000000
# max    30.000000  100.000000

# %%
signal_2.describe()
# Out:
#             Time       Value
# count  31.000000   31.000000
# mean   15.000000   51.612903
# std     9.092121   50.800051
# min     0.000000    0.000000
# 25%     7.500000    0.000000
# 50%    15.000000  100.000000
# 75%    22.500000  100.000000
# max    30.000000  100.000000

# %%
def freq(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2+1]),2.0/N * np.abs(yf[:N//2+1])),columns=['Freq','Ampli'])
    return freq_ampli

# %%
freq_ampli1 = freq(signal_1)
freq_ampli2 = freq(signal_2)

# %%
fig, axs = plt.subplots(2, 2,figsize=(15,15))
axs[0,0].plot(signal_1['Time'], signal_1['Value'])
axs[0,1].stem(freq_ampli1['Freq'], freq_ampli1['Ampli'])
axs[1,0].plot(signal_2['Time'], signal_2['Value'])
axs[1,1].stem(freq_ampli2['Freq'], freq_ampli2['Ampli'])
plt.show()

# %%
freq_ampli_log1 = pd.DataFrame(zip(freq_ampli1['Freq'], np.log(freq_ampli1['Ampli'])),columns=['Freq','Ampli'])
freq_ampli_log2 = pd.DataFrame(zip(freq_ampli2['Freq'], np.log(freq_ampli2['Ampli'])),columns=['Freq','Ampli'])

# %%
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 7)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm

# %%
best_gmm00 = GMM_fit(signal_1)
best_gmm01 = GMM_fit(np.array(signal_1['Value']).reshape(-1,1))
best_gmm02 = GMM_fit(freq_ampli1.iloc[1:,:])
best_gmm03 = GMM_fit(freq_ampli_log1)
best_gmm10 = GMM_fit(signal_2)
best_gmm11 = GMM_fit(np.array(signal_2['Value']).reshape(-1,1))
best_gmm12 = GMM_fit(freq_ampli2.iloc[1:,:])
best_gmm13 = GMM_fit(freq_ampli_log2)

# %% [markdown]
# ## Time Series

# %%
print(best_gmm00)
print(best_gmm10)
# Out:
# GaussianMixture(covariance_type='tied', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=2, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)
# GaussianMixture(covariance_type='tied', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=2, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %%
print(best_gmm00.weights_)
print()
print(best_gmm10.weights_)
# Out:
# [0.4516129 0.5483871]
#
# [0.48387097 0.51612903]

# %%
print(best_gmm00.means_)
print()
print(best_gmm10.means_)
# Out:
# [[ 17.           0.        ]
#  [ 13.35294118 100.        ]]
#
# [[ 16.       0.    ]
#  [ 14.0625 100.    ]]

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10),sharey=True)
sns.distplot(signal_1,kde=False,bins=30,ax=ax1)
z1,_ = best_gmm00.sample(30)
sns.distplot(z1,kde=False,bins=30,ax=ax1)

sns.distplot(signal_2,kde=False,bins=30,ax=ax2)
z2,_ = best_gmm10.sample(30)
sns.distplot(z2,kde=False,bins=30,ax=ax2)
plt.show()

# %%
print(best_gmm00.score(signal_1))
print(best_gmm10.score(signal_2))
# Out:
# 1.7114313221518385
# 1.6921311353546789

# %%
sns.lineplot(z1[:,0],z1[:,1])

# %%
sns.lineplot(z2[:,0],z2[:,1])

# %% [markdown]
# ## Histogram of TS

# %%
print(best_gmm01)
print(best_gmm11)
# Out:
# GaussianMixture(covariance_type='tied', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=2, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)
# GaussianMixture(covariance_type='tied', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=2, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %%
print(best_gmm01.weights_)
print()
print(best_gmm11.weights_)
# Out:
# [0.4516129 0.5483871]
#
# [0.48387097 0.51612903]

# %%
print(best_gmm01.means_)
print()
print(best_gmm11.means_)
# Out:
# [[  0.]
#  [100.]]
#
# [[  0.]
#  [100.]]

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10),sharey=True)
sns.distplot(signal_1['Value'],kde=False,bins=30,ax=ax1)
z1,_ = best_gmm01.sample(30)
#sns.distplot(z1,kde=False,bins=30,ax=ax1)

sns.distplot(signal_2['Value'],kde=False,bins=30,ax=ax2)
z2,_ = best_gmm11.sample(30)
#sns.distplot(z2,kde=False,bins=30,ax=ax2)
plt.show()

# %%
print(best_gmm01.score(np.array(signal_1['Value']).reshape(-1,1)))
print(best_gmm11.score(np.array(signal_2['Value']).reshape(-1,1)))
# Out:
# 5.300359054571703
# 5.296189008020271

# %% [markdown]
# ## Frequency (FFT)

# %%
print(best_gmm02)
print(best_gmm12)
# Out:
# GaussianMixture(covariance_type='diag', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=6, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=6, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %%
print(best_gmm02.weights_)
print()
print(best_gmm12.weights_)
# Out:
# [0.19999986 0.06666667 0.40000016 0.06666667 0.13333333 0.13333332]
#
# [0.06666667 0.19996177 0.06666667 0.06666667 0.53337156 0.06666667]

# %%
print(best_gmm02.means_)
print()
print(best_gmm12.means_)
# Out:
# [[ 0.25806459  8.15205494]
#  [ 0.06451613 60.45500157]
#  [ 0.35483863  2.37520119]
#  [ 0.35483871 14.27988692]
#  [ 0.16129032 16.43811202]
#  [ 0.11290322 12.49647252]]
#
# [[ 0.16129032 63.68922779]
#  [ 0.25809529  6.23124248]
#  [ 0.48387097 21.30260712]
#  [ 0.19354839 12.8696344 ]
#  [ 0.26611692  3.74760516]
#  [ 0.12903226  9.28810153]]

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10),sharey=True)
sns.distplot(freq_ampli1.iloc[1:,:],kde=False,bins=30,ax=ax1)
z1,_ = best_gmm02.sample(30)
#sns.distplot(z1,kde=False,bins=30,ax=ax1)

sns.distplot(freq_ampli2.iloc[1:,:],kde=False,bins=30,ax=ax2)
z2,_ = best_gmm12.sample(30)
#sns.distplot(z2,kde=False,bins=30,ax=ax2)
plt.show()

# %%
plt.scatter(freq_ampli1.iloc[1:,0],freq_ampli1.iloc[1:,1])
plt.scatter(z1[:,0],z1[:,1])

# %%
plt.scatter(freq_ampli2.iloc[1:,0],freq_ampli2.iloc[1:,1])
plt.scatter(z2[:,0],z2[:,1])

# %%
sns.lineplot(z2[:,0],z2[:,1])

# %%
print(best_gmm02.score(freq_ampli1.iloc[1:,:]))
print(best_gmm12.score(freq_ampli2.iloc[1:,:]))
# Out:
# 0.19540494625112614
# 2.24902142595287

# %%
Fs = 30
t = np.arange(0,30,1/Fs)
a=0
y=0
for [i,j] in z1:
    if i > 0:
        y += j*np.sin(2 * np.pi * (i) * t)
for [i,j] in z2:
    if i > 0:
        a += j*np.sin(2 * np.pi * (i) * t)
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10),sharey=True)
ax1.plot(t,y)
ax2.plot(t,a)

# %%
Fs = 30
t = np.arange(0,30,1/Fs)
y = 0
a = 0
for [i,j] in np.array(freq_ampli1):
    y += j*np.sin(2 * np.pi * (i) * t)
for [i,j] in np.array(freq_ampli2):
    a += j*np.sin(2 * np.pi * (i) * t)
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10),sharey=True)
ax1.plot(t,y)
ax2.plot(t,a)

# %%
z2
# Out:
# array([[ 1.60081448e-01,  6.36889707e+01],
#        [ 1.59581372e-01,  6.36897071e+01],
#        [-5.64514542e-02,  4.46350908e+00],
#        [ 4.64392227e-01,  7.44907806e+00],
#        [ 3.97243261e-01,  7.03203839e+00],
#        [ 2.45218283e-01,  6.17465675e+00],
#        [ 2.37122373e-01,  6.03568286e+00],
#        [ 4.82385214e-01,  2.13042767e+01],
#        [ 4.83425742e-01,  2.13035529e+01],
#        [ 1.95821810e-01,  1.28701974e+01],
#        [ 1.94799132e-01,  1.28690581e+01],
#        [ 2.90791293e-01,  3.15173510e+00],
#        [ 4.00553575e-01,  4.04080283e+00],
#        [ 6.25054600e-02,  3.02843005e+00],
#        [ 2.05596870e-01,  3.51657341e+00],
#        [ 1.35593142e-01,  4.94022199e+00],
#        [ 1.56957125e-01,  3.99633769e+00],
#        [ 2.74030833e-01,  3.46879191e+00],
#        [ 4.11675933e-01,  3.89149284e+00],
#        [ 3.07143022e-01,  3.47933953e+00],
#        [ 3.58099527e-01,  4.69034993e+00],
#        [ 2.26068843e-01,  4.18905986e+00],
#        [ 5.53637748e-01,  3.42502130e+00],
#        [ 4.63163661e-01,  3.92429281e+00],
#        [ 1.17151192e-01,  3.54790709e+00],
#        [ 1.95339063e-01,  3.81609815e+00],
#        [ 1.31299824e-01,  9.28849472e+00],
#        [ 1.30108040e-01,  9.28925217e+00],
#        [ 1.30043306e-01,  9.28852377e+00],
#        [ 1.31058658e-01,  9.28809477e+00]])

# %% [markdown]
# ## Log Frequency

# %%
print(best_gmm03)
print(best_gmm13)
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=4, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=6, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %%
print(best_gmm03.weights_)
print()
print(best_gmm13.weights_)
# Out:
# [0.5001092 0.0625    0.125     0.3123908]
#
# [0.37502573 0.125      0.125      0.1875     0.12497427 0.0625    ]

# %%
print(best_gmm03.means_)
print()
print(best_gmm13.means_)
# Out:
# [[ 0.20968002  2.44827564]
#  [ 0.32258065 -0.5831094 ]
#  [ 0.03225806  4.39972141]
#  [ 0.36133916  0.97147542]]
#
# [[0.24193659 1.25271063]
#  [0.08064516 4.39546716]
#  [0.16129032 2.3918024 ]
#  [0.25806452 1.82043961]
#  [0.33872627 1.49551004]
#  [0.48387097 3.05882947]]

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10),sharey=True)

sns.distplot(freq_ampli_log1,kde=True,bins=30,ax=ax1)
z1,_ = best_gmm03.sample(16)
#sns.distplot(z1,kde=True,bins=30,ax=ax1)

sns.distplot(freq_ampli_log2,kde=True,bins=30,ax=ax2)
z2,_ = best_gmm13.sample(16)
#sns.distplot(z2,kde=True,bins=30,ax=ax2)
plt.show()

# %%
print(best_gmm03.score(freq_ampli_log1))
print(best_gmm13.score(freq_ampli_log2))
# Out:
# 0.8413386276378205
# 2.8791208747194528

# %%
Fs = 30
t = np.arange(0,30,1/Fs)
a=0
y=0
for [i,j] in z1:
    y += j*np.sin(2 * np.pi * (i) * t)
for [i,j] in z2:
    a += j*np.sin(2 * np.pi * (i) * t)
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10),sharey=True)
ax1.plot(t,y)
ax2.plot(t,a)

# %%
Fs = 30
t = np.arange(0,30,1/Fs)
y = 0
a = 0
for [i,j] in np.array(freq_ampli_log1):
    y += j*np.sin(2 * np.pi * (i) * t)
for [i,j] in np.array(freq_ampli_log2):
    a += j*np.sin(2 * np.pi * (i) * t)
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10),sharey=True)
ax1.plot(t,y)
ax2.plot(t,a)
