# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy import fftpack
import datetime
from sklearn import mixture
import warnings
warnings.filterwarnings('ignore')
from scipy import fft
from scipy import signal
import math
from acoustics.cepstrum import complex_cepstrum
from acoustics.cepstrum import inverse_complex_cepstrum
from scipy.spatial import distance

# %%
def idft2(yr, yi):
    N, x = yr.shape[0], []
    yr = dict(yr.values)
    yi = dict(yi.values)
    for t in range(N):
        real = 0
        for (k,v),(k2,v2) in zip(yr.items(),yi.items()):
            theta1 = t * (2 * math.pi) * k
            theta2 = t * (2 * math.pi) * k2
            real += (v * math.cos(theta1)) - (v2 * math.sin(theta2))
        x.append(real/N)
    return x

# %%
#Func gives magnitude of FFT provide dataframe in Time Domain
def freq_mag(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data = pd.DataFrame(zip(f,np.abs(yf)),columns=['Freq','Ampli'])
    return fft_data

# %%
#Func gives real and imag of FFT provide dataframe in Time Domain
def freq(df):
    N = df.shape[0]
    y = np.array(df['Value'])
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    fft_data1 = pd.DataFrame(zip(f,yf.real),columns=['Freq','Ampli'])
    fft_data2 = pd.DataFrame(zip(f,yf.imag),columns=['Freq','Ampli'])
    return fft_data1,fft_data2

# %%
def log_freq(df1, df2):
    df1['Ampli'] = np.log(df1["Ampli"])
    df1['Ampli'] = df1['Ampli'].replace([np.inf, -np.inf], 0)
    df1 = df1.fillna(0)
    df2['Ampli'] = np.log(df2["Ampli"])
    df2['Ampli'] = df2['Ampli'].replace([np.inf, -np.inf], 0)
    df2 = df2.fillna(0)
    return df1, df2

# %%
import matplotlib.pyplot as plt
t = np.linspace(0, 1, 500)
s = signal.square(2 * np.pi * 3 * t)
plt.plot(t, s)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
signal_1 = pd.DataFrame(zip(t,s),columns=['Time','Value'])
signal_1
# Out:
#          Time  Value
# 0    0.000000    1.0
# 1    0.002004    1.0
# 2    0.004008    1.0
# 3    0.006012    1.0
# 4    0.008016    1.0
# ..        ...    ...
# 495  0.991984   -1.0
# 496  0.993988   -1.0
# 497  0.995992   -1.0
# 498  0.997996   -1.0
# 499  1.000000    1.0
#
# [500 rows x 2 columns]

# %% [markdown]
# ## Magnitude of Freq

# %%
freq_ampli_mag = freq_mag(signal_1)
plt.plot(freq_ampli_mag['Freq'], freq_ampli_mag['Ampli'])

# %%
value = list(freq_ampli_mag['Ampli'])
ift = fft.ifft(value)
plt.plot(t,ift)

# %% [markdown]
# ## Freq on Real and Imag

# %%
freq_ampli1,freq_ampli1i = freq(signal_1)
fig, axs = plt.subplots(1,2,figsize=(20,10))
axs[0].plot(freq_ampli1['Freq'], freq_ampli1['Ampli'])
axs[1].plot(freq_ampli1i['Freq'], freq_ampli1i['Ampli'])

# %%
value = idft2(freq_ampli1,freq_ampli1i)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 1.4512615234088406e-13

# %% [markdown]
# Recreating the pattern

# %% [markdown]
# ## Log Freq

# %%
log1, log1i = log_freq(freq_ampli1, freq_ampli1i)

# %%
fig, axs = plt.subplots(1,2,figsize=(20,10))
axs[0].plot(log1['Freq'], log1['Ampli'])
axs[1].plot(log1i['Freq'], log1i['Ampli'])

# %%
log1["Ampli"] = np.exp(log1["Ampli"])
log1i["Ampli"] = np.exp(log1i["Ampli"])
value = idft2(log1,log1i)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 11.347297102906662

# %% [markdown]
# ## Cepstrum

# %%
duration = signal_1.shape[0]
fs = 1.0
samples = int(fs*duration)
t = np.arange(samples) / fs
ceps, _ = complex_cepstrum(signal_1['Value'])
print(ceps)
# Out:
# [ 6.95344405e-01  9.95082235e-01 -3.31162124e-01  3.28516250e-01
#  -1.64520877e-01  1.95279296e-01 -1.08990168e-01  1.38228795e-01
#  -8.12366811e-02  1.06571352e-01 -6.45937688e-02  8.64543860e-02
#  -5.35058931e-02  7.25501069e-02 -4.55921184e-02  6.23723093e-02
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
distance.euclidean(signal_1["Value"],incep)
# Out:
# 1.4502759697883445e-14

# %% [markdown]
# # GMM of All

# %% [markdown]
# ## GMM on Time Series

# %%
def GMM_fit(df):
    dfx = df
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, 100)
    cv_types = ['spherical', 'tied', 'diag', 'full']
    for cv_type in cv_types:
        for n_components in n_components_range:
            # Fit a Gaussian mixture with EM
            gmm = mixture.GaussianMixture(n_components=n_components,
                                          covariance_type=cv_type)
            gmm.fit(dfx)
            bic.append(gmm.bic(dfx))
            if bic[-1] < lowest_bic:
                lowest_bic = bic[-1]
                best_gmm = gmm
    return best_gmm

# %%
ts = GMM_fit(signal_1)
print(ts, '\n')
print('WEIGHTS -', ts.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', ts.means_, '\n')
# Out:
# GaussianMixture(covariance_type='tied', n_components=6)
#
# WEIGHTS - [0.166      0.16600004 0.166      0.16799999 0.16799997 0.166     ]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 0.91583157 -1.        ]
#  [ 0.41683368  1.        ]
#  [ 0.25050109 -1.        ]
#  [ 0.08316641  1.        ]
#  [ 0.7524811   1.        ]
#  [ 0.58316633 -1.        ]]

# %%
z,_ = ts.sample(500)
plt.title('Actual data')
sns.lineplot(signal_1['Time'], signal_1['Value'])
plt.show()
plt.title('Values given by GMM')
sns.lineplot(z[:,0],z[:,1])
plt.show()

# %%
distance.euclidean(signal_1["Value"], z[:, 1])
# Out:
# 36.55158865731983

# %% [markdown]
# ## GMM on Real and Img Freq

# %%
freq_ampli1,freq_ampli1i = freq(signal_1)

# %%
fr = GMM_fit(freq_ampli1)                        # GMM on real part of FFT data
fi = GMM_fit(freq_ampli1i)                      # GMM on imaginary part of FFT data

# %%
print(fr, '\n')
print('WEIGHTS -', fr.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',fr.means_, '\n')
# Out:
# GaussianMixture(n_components=44)
#
# WEIGHTS - [2.94778861e-02 1.40370413e-02 9.77382474e-03 3.79808998e-02
#  2.79939635e-02 2.19220396e-02 1.04193105e-02 3.62255917e-02
#  1.19621236e-02 1.15101762e-02 1.42634051e-02 2.93439820e-02
#  9.33798228e-03 3.85824083e-02 1.16183919e-02 2.16666996e-07
#  1.19817128e-02 9.73399859e-03 2.36828914e-02 4.88565865e-02
#  3.20263026e-02 3.68030578e-02 2.26949998e-02 3.99881495e-02
#  9.31132915e-03 1.40418237e-02 2.41952067e-02 3.52461166e-02
#  2.99842098e-02 1.58888036e-02 2.83784578e-02 1.00144525e-02
#  1.99911283e-03 3.74683842e-02 7.22318627e-02 3.61479408e-02
#  1.08893637e-02 1.44219068e-02 1.41809014e-02 1.51505676e-02
#  2.00906847e-02 1.60977712e-02 3.98560904e-02 1.41880714e-02]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 2.36217287e-01  5.72171490e-01]
#  [-1.01847017e-01  7.34952269e+00]
#  [ 3.92781259e-01 -5.30007293e+00]
#  [-3.28222759e-01  1.28013395e+00]
#  [ 4.63480890e-01 -4.32980807e-02]
#  [-3.57295060e-01 -5.47689168e-01]
#  [-1.88197890e-01  6.00257775e+00]
#  [ 1.94810478e-01 -1.51957615e+00]
#  [ 4.58094048e-01 -5.86767312e+00]
#  [-4.03381861e-01  2.44864467e-01]
#  [ 4.45476781e-01  7.47697593e-01]
#  [ 9.24333366e-02  1.57642974e+00]
#  [ 6.29483312e-03  7.98075474e+00]
#  [-1.74875850e-01  6.94651889e-01]
#  [-1.78785866e-01  2.46610985e+00]
#  [-1.50000000e-01  6.69571753e+00]
#  [-4.70044954e-01 -5.91967222e+00]
#  [-4.04766204e-01 -5.44092454e+00]
#  [ 3.04199427e-01 -3.39637321e-01]
#  [-4.66137125e-01 -4.16960233e-02]
#  [-2.72836746e-01  1.09490523e+00]
#  [ 2.19525254e-02  1.87706196e+00]
#  [ 1.36650516e-01  1.10474559e+00]
#  [ 3.02240350e-01  3.57805223e+00]
#  [-3.47558086e-01 -4.64408342e+00]
#  [-3.72645561e-01  2.27498974e-02]
#  [-1.82616227e-01 -1.24509898e+00]
#  [ 4.09010686e-01  1.31148080e-01]
#  [-3.86500199e-02  2.49322084e+00]
#  [ 1.30493681e-01  6.96377112e+00]
#  [-3.03439933e-01  3.55096867e+00]
#  [ 3.33149221e-01 -4.39602078e+00]
#  [-1.50000000e-01  6.69571753e+00]
#  [-2.31648754e-01  8.72744610e-01]
#  [-2.35574732e-03  2.04064648e+00]
#  [ 2.76281375e-01  1.07068317e+00]
#  [-2.85534489e-01 -3.47948041e+00]
#  [ 1.49317610e-02  7.82949499e+00]
#  [-6.67934746e-02  1.05537809e+00]
#  [-4.35025781e-01  9.15005298e-01]
#  [ 1.42274217e-01  2.55723123e+00]
#  [ 4.23775924e-01 -5.20414959e-01]
#  [ 3.22987985e-01  1.32511678e+00]
#  [-1.07490856e-01  1.79241155e+00]]

# %%
print(fi, '\n')
print('WEIGHTS -', fi.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',fi.means_, '\n')
# Out:
# GaussianMixture(n_components=56)
#
# WEIGHTS - [0.02184059 0.002      0.002      0.002      0.002      0.002
#  0.002      0.02947234 0.002      0.0183722  0.002      0.002
#  0.002      0.0111417  0.002      0.04474965 0.002      0.002
#  0.002      0.02207036 0.002      0.002      0.04670792 0.05403942
#  0.002      0.002      0.002      0.002      0.02138225 0.002
#  0.002      0.02059551 0.02518089 0.0217781  0.04352271 0.002
#  0.002      0.002      0.02338262 0.04220676 0.0151374  0.05122708
#  0.04874576 0.0300958  0.002      0.00668995 0.002      0.05192625
#  0.002      0.03363459 0.06878232 0.04564187 0.002      0.03025156
#  0.10233826 0.01108614]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[-2.02408288e-01 -1.97101684e+00]
#  [-6.00000000e-03  3.18154925e+02]
#  [ 6.00000000e-03 -3.18154925e+02]
#  [-5.40000000e-02  3.39901646e+01]
#  [ 4.20000000e-02 -4.43960840e+01]
#  [-1.80000000e-02  1.05638982e+02]
#  [ 1.80000000e-02 -1.05638982e+02]
#  [ 1.87497789e-01  4.77341163e+00]
#  [ 9.00000000e-02 -1.89751247e+01]
#  [ 2.56721640e-01  7.21347197e-01]
#  [-3.00000000e-02  6.28900218e+01]
#  [-1.38000000e-01  1.05553715e+01]
#  [ 3.00000000e-02 -6.28900218e+01]
#  [-1.70298389e-01 -4.97073275e+00]
#  [-9.00000000e-02  1.89751247e+01]
#  [-2.92748437e-01 -2.21169026e-01]
#  [ 5.40000000e-02 -3.39901646e+01]
#  [ 1.26000000e-01 -1.21175460e+01]
#  [-4.20000000e-02  4.43960840e+01]
#  [ 1.64543656e-01  2.07331009e+00]
#  [-6.60000000e-02  2.72638737e+01]
#  [ 6.60000000e-02 -2.72638737e+01]
#  [ 6.84807695e-02 -2.40072471e+00]
#  [ 4.07432471e-01  4.38622307e-01]
#  [ 1.50000000e-01 -9.21586455e+00]
#  [-1.14000000e-01  1.39681599e+01]
#  [ 7.80000000e-02 -2.25223279e+01]
#  [-1.86000000e-01  6.13255690e+00]
#  [-2.02142656e-01 -1.19732800e+00]
#  [-7.80000000e-02  2.25223279e+01]
#  [ 1.14000000e-01 -1.39681599e+01]
#  [-2.66494399e-01  2.32644289e+00]
#  [ 2.32466333e-01 -3.84204966e+00]
#  [ 2.02662554e-01  1.19738180e+00]
#  [-4.73820867e-01 -1.62270282e-01]
#  [-1.50000000e-01  9.21586455e+00]
#  [ 1.02000000e-01 -1.62042719e+01]
#  [-1.02000000e-01  1.62042719e+01]
#  [-1.77736964e-01 -4.72242833e+00]
#  [ 4.72602319e-01  1.68908220e-01]
#  [-3.15860656e-01 -8.03808204e-01]
#  [ 5.43329638e-02 -6.49679001e-01]
#  [-4.95840528e-02  6.89346624e-01]
#  [-3.69251699e-01 -2.94079905e+00]
#  [-1.26000000e-01  1.21175460e+01]
#  [ 7.29829480e-02  5.09270845e+00]
#  [ 1.38000000e-01 -1.05553715e+01]
#  [-7.17197818e-02  2.35331376e+00]
#  [-1.62000000e-01  8.05292934e+00]
#  [ 2.98221784e-01 -1.10750241e-01]
#  [ 3.44369432e-01  1.09517837e+00]
#  [ 2.35797682e-04  1.75207786e-03]
#  [-1.74000000e-01  7.03333794e+00]
#  [ 3.80948896e-01  2.71140430e+00]
#  [-3.86610511e-01 -7.11250906e-01]
#  [-1.96318092e-01 -2.11965716e+00]]

# %%
z1,_ = fr.sample(500)
z1i,_ = fi.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].stem(freq_ampli1['Freq'], freq_ampli1['Ampli'])
#plt.show()
ax[1].stem(z1[:, 0], z1[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].scatter(freq_ampli1i['Freq'], freq_ampli1i['Ampli'])
#plt.show()
ax[1].scatter(z1i[:, 0], z1i[:, 1])
plt.show()

# %%
fr_d = pd.DataFrame(zip(z1[:,0],z1[:,1]),columns=['Freq','Ampli'])
fi_d = pd.DataFrame(zip(z1i[:,0],z1i[:,1]),columns=['Freq','Ampli'])
value = idft2(fr_d,fi_d)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"], value)
# Out:
# 13.866932869015496

# %% [markdown]
# ## GMM on Log-Freq

# %%
lr = GMM_fit(log1)                        # GMM on real part of FFT data
li = GMM_fit(log1i)

# %%
print(lr, '\n')
print('WEIGHTS -', lr.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',lr.means_, '\n')
# Out:
# GaussianMixture(n_components=39)
#
# WEIGHTS - [0.02910473 0.00798983 0.02365407 0.02948748 0.12561091 0.010187
#  0.00948313 0.05345591 0.00232718 0.02149627 0.0098718  0.02659736
#  0.0147884  0.00898287 0.00649009 0.05058925 0.01485411 0.00199955
#  0.00989154 0.01063209 0.03652616 0.02423825 0.02606363 0.02433289
#  0.00288761 0.03835315 0.01445092 0.02110954 0.03570816 0.00790625
#  0.01483686 0.03962512 0.00969507 0.12338911 0.01446949 0.0105794
#  0.03764456 0.00801382 0.04267645]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[ 1.56126550e-01  8.63967555e-01]
#  [ 7.18994008e-02  7.67647019e+00]
#  [ 4.07498476e-01  1.55347580e-01]
#  [-1.18074763e-02  2.48745336e+00]
#  [-3.52664950e-01  1.00000000e+00]
#  [ 1.80492749e-01  6.14826660e+00]
#  [ 5.06306210e-03  7.98174336e+00]
#  [ 1.43131601e-03  2.05748844e+00]
#  [ 3.25159629e-01  1.05192170e+00]
#  [-4.14208798e-01  1.53537917e-01]
#  [ 4.63639974e-01  4.66818205e-01]
#  [ 2.90683972e-01  3.82722051e+00]
#  [ 4.78791498e-01  3.16763418e-02]
#  [ 1.23140877e-01  7.09239271e+00]
#  [-7.38997841e-03  7.91303489e+00]
#  [-1.44971423e-02  1.90143336e+00]
#  [-7.33366602e-02  9.36563723e-01]
#  [-1.02000000e-01  7.37788216e+00]
#  [-4.63626871e-01  4.67053962e-01]
#  [-4.01756789e-01  1.48956320e+00]
#  [ 2.77632675e-01  1.06170544e+00]
#  [-1.57813415e-02  1.97015404e+00]
#  [-2.91794699e-01  3.80301568e+00]
#  [-1.71030207e-01  7.28748025e-01]
#  [-6.28757537e-04  1.05749086e+00]
#  [ 3.20813819e-01  1.34508846e+00]
#  [ 9.60989450e-02  1.76276366e+00]
#  [ 3.95945487e-04  2.61433247e+00]
#  [ 2.22814985e-01  9.35291773e-01]
#  [-1.31903490e-01  6.96972441e+00]
#  [-4.78850838e-01  3.16674085e-02]
#  [-3.22047652e-01  1.33342860e+00]
#  [-1.84923908e-01  6.06646587e+00]
#  [ 3.50661761e-01  1.00000000e+00]
#  [ 7.43839928e-02  9.20651194e-01]
#  [ 4.02010257e-01  1.48474838e+00]
#  [-2.77989547e-01  1.05924062e+00]
#  [-7.19480120e-02  7.67603767e+00]
#  [-2.10682152e-01  1.01777792e+00]]

# %%
print(li, '\n')
print('WEIGHTS -', li.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n',li.means_, '\n')
# Out:
# GaussianMixture(n_components=21)
#
# WEIGHTS - [0.00396316 0.002      0.002      0.002      0.002      0.02476625
#  0.002      0.002      0.002      0.012077   0.05140248 0.10477223
#  0.01991128 0.0571218  0.50155955 0.002      0.0266384  0.04631382
#  0.002      0.10566259 0.02781143]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[-1.60980155e-01  1.03096661e+00]
#  [-6.00000000e-03  3.18154925e+02]
#  [-1.80000000e-02  1.05638982e+02]
#  [-4.20000000e-02  4.43960840e+01]
#  [-9.00000000e-02  1.89751247e+01]
#  [ 1.68001975e-01  4.88936509e+00]
#  [-3.00000000e-02  6.28900218e+01]
#  [-5.40000000e-02  3.39901646e+01]
#  [-6.60000000e-02  2.72638737e+01]
#  [-1.44275942e-01  1.01307390e+01]
#  [-6.13127685e-02  2.50085236e+00]
#  [ 3.80326900e-01  6.65770817e-01]
#  [-2.40172957e-01  3.36900516e+00]
#  [ 1.85653281e-01  1.88022704e+00]
#  [-1.78254141e-01  1.00000000e+00]
#  [-7.80000000e-02  2.25223279e+01]
#  [ 3.22415088e-01  3.77351989e+00]
#  [ 4.69679219e-01  1.86180762e-01]
#  [-1.02000000e-01  1.62042719e+01]
#  [ 7.66742746e-02  4.94464321e-01]
#  [ 2.38573296e-01  1.23852580e+00]]

# %%
z2,_ = lr.sample(500)
z2i,_ = li.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].stem(log1['Freq'], log1['Ampli'])
#plt.show()
ax[1].stem(z2[:, 0], z2[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].scatter(log1i['Freq'], log1i['Ampli'])
#plt.show()
ax[1].scatter(z2i[:, 0], z2i[:, 1])
plt.show()

# %%
lr_d = pd.DataFrame(zip(z2[:,0],np.exp(z2[:,1])),columns=['Freq','Ampli'])
li_d = pd.DataFrame(zip(z2i[:,0],np.exp(z2i[:,1])),columns=['Freq','Ampli'])
value = idft2(lr_d,li_d)
plt.plot(value)

# %%
distance.euclidean(signal_1["Value"],value)
# Out:
# 4.745449722653933e+136

# %% [markdown]
# ## GMM on Cepstrum

# %%
c1 = np.array(ceps).reshape(-1, 1)
c = GMM_fit(c1)

# %%
print(c, '\n')
print('WEIGHTS -', c.weights_, '\n')
print('MEANS (Col 1: Freq; Col 2: Amplitude) - \n', c.means_, '\n')
# Out:
# GaussianMixture(n_components=3)
#
# WEIGHTS - [0.75384716 0.03684054 0.20931231]
#
# MEANS (Col 1: Freq; Col 2: Amplitude) -
#  [[-0.00083831]
#  [ 0.05394543]
#  [ 0.00014749]]

# %%
z3,_ = c.sample(500)

# %%
fig, ax = plt.subplots(2, sharex='all', sharey='all')
ax[0].plot(t, ceps)
#plt.show()
ax[1].plot(t, z3.flatten())
plt.show()

# %%
gmm_incep = inverse_complex_cepstrum(z3, np.array(1.0))    # inverse ceps
plt.plot(signal_1['Time'], gmm_incep)

# %%
distance.euclidean(signal_1['Value'], gmm_incep)
# Out:
# 31.579583992148343
